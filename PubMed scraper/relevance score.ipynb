# %% [markdown]
# # Relevance Score
# For each paper we have to compute a relevance score which should state how relevant that paper is compared to the search we made. <br>
#
# So i was thinking something like this:<br>
# paper1 ---> score : 1 (exactly what we were looking for)<br>
# paper2 ---> score : 0 (treats a completly different topic)<br>
# and the rest of the cases are between 0 and 1
#
# Strategies:
# - [Title Matches](#section_id)
# - [Keywords matches](#section_id2)
# - [Title and Keywords matches](#section_id3)
# - [Automatic dictionary from abstracts](#section_id4)
# - [Automatic dictionary from keywords](#section_id5)

# %%
import requests
import json
import time
import pandas as pd

# %%
def esearch(search_term):
    search_term = search_term.strip().replace(' ', '+')
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi'
    url = url + '?db=pubmed' + '&retmode=json' + '&retmax=100'
    url = url + '&term=' + search_term
    site = requests.get(url).content
    json_site = json.loads(site.decode()) 
    UIDs = json_site['esearchresult']['idlist']
    return UIDs

# %%
def efetch(UIDs):
    session = requests.Session()
    abstracts = []
    keywords = []
    titles = []
    i = 1
    for UID in UIDs:
        time.sleep(0.4)
        url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi'
        url = url + '?db=pubmed' + '&rettype=medline&id='
        url = url + UID
        
        data = session.get(url).content
        data = data.decode()
        data = data.split('\n')
        
        
        ls = []
        for elem in data:
            if elem == '':
                continue
            elif elem[0:4] != '    ': 
                elem = elem.strip()
                elem = elem.replace('\n', '')
                ls.append(elem)
            else:                    
                elem = elem.strip()
                elem = elem.replace('\n', '')
                ls[-1] = ls[-1] + elem
    
    
        ls_2 = [] 
        for elem in ls:
            key = elem[0:4].strip()
            value = elem[5:].strip()
            ls_2.append([key, value])
        
        all_key = ''
        abst = ''
        for row in ls_2:
            if row[0] == 'AB':
                abst = abst + row[1]
            
            elif row[0] == 'OT' or row[0] == 'MH':
                all_key = all_key + row[1] + ', '
            
            elif row[0] == 'TI':
                titles.append(row[1])
                
        keywords.append(all_key[:-2])
        abstracts.append(abst)
        
        if i%5==0:
            print('Paper ' + str(i) +': OK')
        i += 1
        
    dic = {
        'UID' : UIDs,
        'title' : titles,
        'abstarct' : abstracts,
        'keywords' : keywords
    }
    return dic

# %%
UIDs = esearch('machine learning cancer prevention')
data = efetch(UIDs)
# Out:
# Paper 5: OK
# Paper 10: OK
# Paper 15: OK
# Paper 20: OK
# Paper 25: OK
# Paper 30: OK
# Paper 35: OK
# Paper 40: OK
# Paper 45: OK
# Paper 50: OK
# Paper 55: OK
# Paper 60: OK
# Paper 65: OK
# Paper 70: OK
# Paper 75: OK
# Paper 80: OK
# Paper 85: OK
# Paper 90: OK
# Paper 95: OK
# Paper 100: OK

# %%
df = pd.DataFrame(data)
df
# Out:
#          UID                                              title  \
# 0   36179551  Baseline host determinants of robust human HIV...
# 1   36168036  Molecular pathways enhance drug response predi...
# 2   36159773  Comparative Analysis of Machine Learning Metho...
# 3   36159011  Radiomics and nomogram of magnetic resonance i...
# 4   36157578  The integrated landscape of eRNA in gastric ca...
# ..       ...                                                ...
# 95  35316197  Artificial Intelligence for Colonoscopy: Past,...
# 96  35304310  Urine surface-enhanced Raman spectroscopy comb...
# 97  35272662  Reinforcement learning evaluation of treatment...
# 98  35269943  Personalized Risk Schemes and Machine Learning...
# 99  35239414  Simple Linear Cancer Risk Prediction Models Wi...
#
#                                              abstarct  \
# 0   BACKGROUND: The identification of baseline hos...
# 1   Computational models have been successful in p...
# 2   Breast cancer is the leading cancer in women, ...
# 3   BACKGROUND: Microvascular invasion (MVI) of sm...
# 4   The comprehensive regulation effect of eRNA on...
# ..                                                ...
# 95  During the past decades, many automated image ...
# 96  In this paper, we investigated the feasibility...
# 97  BACKGROUND: Evaluation of new treatment polici...
# 98  Myelodysplastic syndromes (MDS) are characteri...
# 99  PURPOSE: The ability to accurately predict an ...
#
#                                              keywords
# 0   Antibody, Baseline characteristics, CD4+ T cel...
# 1   Cell Line, Cell Line, Tumor, *Everolimus, Hete...
# 2   *Breast Neoplasms/diagnosis/genetics, Female, ...
# 3   *Carcinoma, Hepatocellular/diagnostic imaging/...
# 4   Bioinformatics, Biological sciences, Cancer, S...
# ..                                                ...
# 95  Algorithms, *Artificial Intelligence, Colonosc...
# 96  Algorithms, Biomarkers, Tumor, *Carcinoma, Hep...
# 97  Aspartate Aminotransferases/therapeutic use, H...
# 98  Chromosome Aberrations, Genomics/methods, Huma...
# 99  *Breast Neoplasms/diagnosis/epidemiology/etiol...
#
# [100 rows x 4 columns]

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Title matches
# one strategy might be to see if there is a match between the search term and the title <br>
# we can compute the score like: (matching terms in the title)/(total search terms)

# %%
def process_text(text):
    text = text.strip()
    text = text.lower()
    text = text.replace('.', '')
    text = text.replace(',', '')
    text = text.replace(':', '')
    text = text.replace(';', '')
    text = text.replace('*', '')
    text = text.replace('/', ' ')
    return text

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
titles = df['title'].tolist()
for title in titles:
    title = process_text(title)
    matchs = 0
    for word in search_term:
        if word in title:
            matchs += 1
    scores.append(matchs/len(search_term))

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2
# Out:
#                                                 title  score
# 18  Identification of Hub Genes Associated with Tu...   0.75
# 83  A Machine-Learning-Based Bibliometric Analysis...   0.75
# 29  Decoding the Role of Epigenetics in Breast Can...   0.75
# 70  Recent advancement in cancer diagnosis using m...   0.75
# 25  Machine Learning-based Correlation Study betwe...   0.75
# ..                                                ...    ...
# 24  Positive-gradient-weighted object activation m...   0.00
# 73  Ferroptosis-based molecular prognostic model f...   0.00
# 47  The Appalachia Mind Health Initiative (AMHI): ...   0.00
# 76  SRG-Vote: Predicting Mirna-Gene Relationships ...   0.00
# 0   Baseline host determinants of robust human HIV...   0.00
#
# [100 rows x 2 columns]

# %%
 for elem in df2[df2['score']==0.75]['title'].values:
        print(elem)
        print()
# Out:
# Identification of Hub Genes Associated with Tumor-infiltrating Immune Cells andECM Dynamics as the Potential Therapeutic Targets in Gastric Cancer through anIntegrated Bioinformatic Analysis and Machine Learning Methods.
#
# A Machine-Learning-Based Bibliometric Analysis of the Scientific Literature onAnal Cancer.
#
# Decoding the Role of Epigenetics in Breast Cancer Using Formal Modeling andMachine-Learning Methods.
#
# Recent advancement in cancer diagnosis using machine learning and deep learningtechniques: A comprehensive review.
#
# Machine Learning-based Correlation Study between Perioperative ImmunonutritionalIndex and Postoperative Anastomotic Leakage in Patients with Gastric Cancer.
#
# Machine Learning for Endometrial Cancer Prediction and Prognostication.
#
# Machine learning-based demand forecasting in cancer palliative care homehospitalization.
#
# Risk Prediction of Pancreatic Cancer in Patients With Recent-onset Hyperglycemia:A Machine-learning Approach.
#
# Development of Training Materials for Pathologists to Provide Machine LearningValidation Data of Tumor-Infiltrating Lymphocytes in Breast Cancer.
#
# Effective Image Processing and Segmentation-Based Machine Learning Techniques forDiagnosis of Breast Cancer.
#
# Development and Validation of Machine Learning Models to Predict Epidermal GrowthFactor Receptor Mutation in Non-Small Cell Lung Cancer: A Multi-CenterRetrospective Radiomics Study.
#
# Development and Validation of a Non-Invasive, Chairside Oral Cavity Cancer RiskAssessment Prototype Using Machine Learning Approach.
#
# A Comparison of Logistic Regression Against Machine Learning Algorithms forGastric Cancer Risk Prediction Within Real-World Clinical Data Streams.
#
# Comparative Analysis of Machine Learning Methods for Breast Cancer Classificationin Genetic Sequences.
#
# Artificial Intelligence and Machine Learning in Cancer Research: A Systematic andThematic Analysis of the Top 100 Cited Articles Indexed in Scopus Database.

# %% [markdown]
# <a id='section_id2'></a>

# %% [markdown]
# # Keywords matches
# same as title but for keywords

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
keywords = df['keywords'].tolist()
for keys in keywords:
    keys = process_text(keys)
    matchs = 0
    for word in search_term:
        if word in keys:
            matchs += 1
    scores.append(matchs/len(search_term))

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2
# Out:
#                                                 title  score
# 69  Artificial intelligence for the prevention and...    1.0
# 53  Artificial Intelligence and Machine Learning i...    1.0
# 38  Increasing Women's Knowledge about HPV Using B...    1.0
# 84  Association between Serum Triglycerides and Pr...    1.0
# 35  Quantitative ultrasound image analysis of axil...    1.0
# ..                                                ...    ...
# 16  Vascular Implications of COVID-19: Role of Rad...    0.0
# 65  Chronic Lymphocytic Leukemia Progression Diagn...    0.0
# 74  Power of big data to improve patient care in g...    0.0
# 45  Computational identification of natural produc...    0.0
# 0   Baseline host determinants of robust human HIV...    0.0
#
# [100 rows x 2 columns]

# %%
for elem in df2[df2['score']==1.0]['title'].values:
        print(elem)
        print()
# Out:
# Artificial intelligence for the prevention and clinical management ofhepatocellular carcinoma.
#
# Artificial Intelligence and Machine Learning in Cancer Research: A Systematic andThematic Analysis of the Top 100 Cited Articles Indexed in Scopus Database.
#
# Increasing Women's Knowledge about HPV Using BERT Text Summarization: An OnlineRandomized Study.
#
# Association between Serum Triglycerides and Prostate Specific Antigen (PSA) amongU.S. Males: National Health and Nutrition Examination Survey (NHANES), 2003-2010.
#
# Quantitative ultrasound image analysis of axillary lymph nodes to differentiatemalignancy from reactive benign changes due to COVID-19 vaccination.

# %% [markdown]
# <a id='section_id3'></a>

# %% [markdown]
# # Title and Keywords matches

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
keywords = df['keywords'].tolist()
titles = df['title'].tolist()
for i in range(len(titles)):
    titles[i] = process_text(titles[i])
    keywords[i] = process_text(keywords[i])
    matchs = 0
    for word in search_term:
        if word in keywords[i]:
            matchs += 1
        if word in titles[i]:
            matchs += 1
    scores.append(matchs)

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2['score'] = df2['score'].apply(lambda x: x/max(df2['score']))
df2
# Out:
#                                                 title     score
# 53  artificial intelligence and machine learning i...  1.000000
# 83  a machine-learning-based bibliometric analysis...  0.857143
# 21  machine learning for endometrial cancer predic...  0.857143
# 75  machine learning-based demand forecasting in c...  0.857143
# 18  identification of hub genes associated with tu...  0.857143
# ..                                                ...       ...
# 41  abstracts of presentations at the association ...  0.000000
# 57  precision medicine journey through omics approach  0.000000
# 47  the appalachia mind health initiative (amhi) a...  0.000000
# 52  automatic segmentation of calcification areas ...  0.000000
# 0   baseline host determinants of robust human hiv...  0.000000
#
# [100 rows x 2 columns]

# %%
for elem in df2.head(10)['title'].values:
        print(elem)
        print()
# Out:
# artificial intelligence and machine learning in cancer research a systematic andthematic analysis of the top 100 cited articles indexed in scopus database
#
# a machine-learning-based bibliometric analysis of the scientific literature onanal cancer
#
# machine learning for endometrial cancer prediction and prognostication
#
# machine learning-based demand forecasting in cancer palliative care homehospitalization
#
# identification of hub genes associated with tumor-infiltrating immune cells andecm dynamics as the potential therapeutic targets in gastric cancer through anintegrated bioinformatic analysis and machine learning methods
#
# development and validation of a non-invasive chairside oral cavity cancer riskassessment prototype using machine learning approach
#
# recent advancement in cancer diagnosis using machine learning and deep learningtechniques a comprehensive review
#
# development and validation of machine learning models to predict epidermal growthfactor receptor mutation in non-small cell lung cancer a multi-centerretrospective radiomics study
#
# machine learning-based correlation study between perioperative immunonutritionalindex and postoperative anastomotic leakage in patients with gastric cancer
#
# effective image processing and segmentation-based machine learning techniques fordiagnosis of breast cancer

# %% [markdown]
# <a id='section_id4'></a>

# %% [markdown]
# # Automatic dictionary from abstracts
# idea of the tutor i overheard <br>
# basically build a dictionary of the most common words in the abstracts and then use this list to check for matches (in title? in abstract? i have no idea)

# %%
def process_text(text):
    text = text.strip()
    text = text.lower()
    text = text.replace('.', '')
    text = text.replace(',', '')
    text = text.replace(':', '')
    text = text.replace(';', '')
    text = text.replace('*', '')
    text = text.replace('/', ' ')
    return text

# %%
def word_freq(text, dic):
    text = process_text(text)
    text = text.split()
    for word in text:
        if word not in dic:
            dic[word] = 0
        dic[word] += 1
    return dic

# %%
abstracts = df['abstarct'].tolist()
dic = {}
for abstract in abstracts:
    dic = word_freq(abstract, dic)

# %%
dic = {key: val for key, val in sorted(dic.items(), key = lambda ele: ele[1], reverse = True)}

# %%
# most common words are not the one we care about
dic
# Out:
# {'the': 1568,
#  'of': 1300,
#  'and': 1279,
#  'to': 728,
#  'in': 721,
#  'a': 513,
#  'for': 406,
#  'with': 374,
#  'is': 217,
#  'were': 211,
#  'that': 198,
#  'on': 190,
#  'this': 184,
#  'was': 184,
#  'we': 182,
#  'cancer': 175,
#  'as': 168,
#  'by': 159,
#  'patients': 159,
#  'from': 155,
#  'be': 142,
#  'are': 136,
#  'model': 125,
#  'data': 118,
#  'an': 117,
#  'learning': 113,
#  'clinical': 103,
#  'study': 101,
#  'machine': 95,
#  'results': 90,
#  'using': 89,
#  'models': 89,
#  'can': 88,
#  'at': 80,
#  'methods': 76,
#  'risk': 74,
#  'these': 73,
#  'or': 72,
#  'based': 67,
#  'covid-19': 61,
#  'used': 60,
#  'treatment': 60,
#  'our': 59,
#  'has': 58,
#  'health': 58,
#  'prediction': 57,
#  'diagnosis': 56,
#  'analysis': 56,
#  'detection': 55,
#  '1': 54,
#  'have': 54,
#  'between': 54,
#  'disease': 53,
#  'may': 50,
#  'which': 50,
#  'most': 48,
#  'been': 47,
#  'all': 46,
#  'identify': 46,
#  'also': 45,
#  'accuracy': 45,
#  'genes': 45,
#  'research': 44,
#  'it': 44,
#  'patient': 43,
#  'upon': 43,
#  'not': 42,
#  'should': 41,
#  'early': 41,
#  'prevention': 41,
#  'participants': 40,
#  'will': 40,
#  'more': 40,
#  'ai': 40,
#  'able': 40,
#  'features': 39,
#  'had': 39,
#  'testing': 39,
#  '2': 39,
#  'care': 38,
#  'activity': 38,
#  'completion': 38,
#  'performance': 37,
#  'such': 37,
#  'system': 37,
#  'use': 37,
#  'tumor': 36,
#  'potential': 36,
#  'ml': 36,
#  'showed': 35,
#  'high': 34,
#  '=': 34,
#  'associated': 34,
#  'mortality': 34,
#  'improve': 33,
#  'support': 33,
#  'survival': 33,
#  'into': 33,
#  'after': 33,
#  'medicine': 33,
#  'university': 33,
#  'both': 32,
#  'studies': 32,
#  'breast': 32,
#  'role': 32,
#  'validation': 32,
#  'method': 32,
#  'factors': 32,
#  'cells': 32,
#  'sensitivity': 31,
#  'other': 31,
#  'imaging': 31,
#  'however': 31,
#  'could': 30,
#  'images': 30,
#  'group': 30,
#  'than': 30,
#  'development': 30,
#  'background': 29,
#  'response': 29,
#  'including': 29,
#  'identified': 29,
#  'hospital': 29,
#  'specificity': 29,
#  'their': 29,
#  'screening': 29,
#  'network': 28,
#  'pathology': 28,
#  '3': 28,
#  'cases': 28,
#  'ci': 27,
#  'cell': 27,
#  'samples': 27,
#  'algorithm': 27,
#  'algorithms': 27,
#  'sars-cov-2': 27,
#  'new': 27,
#  'louisville': 27,
#  'outcomes': 26,
#  'two': 26,
#  'total': 26,
#  'blood': 26,
#  'well': 26,
#  'its': 26,
#  'women': 25,
#  'develop': 25,
#  'expression': 25,
#  'found': 25,
#  'intelligence': 25,
#  'need': 25,
#  'levels': 25,
#  'curve': 24,
#  'diagnostic': 24,
#  'techniques': 24,
#  'training': 24,
#  'while': 24,
#  'management': 24,
#  'when': 23,
#  'higher': 23,
#  'drug': 23,
#  'developed': 23,
#  'regression': 23,
#  'predictive': 23,
#  'neural': 23,
#  'test': 23,
#  'conclusions': 23,
#  'during': 23,
#  'how': 23,
#  'gene': 23,
#  'describe': 23,
#  'immune': 22,
#  'three': 22,
#  'significant': 22,
#  'molecular': 22,
#  'score': 22,
#  'increased': 22,
#  'evaluated': 22,
#  'only': 22,
#  'different': 22,
#  'artificial': 22,
#  'time': 22,
#  'medical': 22,
#  'deep': 22,
#  'application': 22,
#  'various': 22,
#  'approach': 21,
#  'precision': 21,
#  'important': 21,
#  'compared': 21,
#  'effect': 21,
#  'predict': 21,
#  'mass': 21,
#  'healthcare': 21,
#  'due': 21,
#  'among': 20,
#  'overall': 20,
#  'classification': 20,
#  'tumors': 20,
#  'forest': 20,
#  'cohort': 20,
#  'value': 20,
#  'one': 20,
#  'therapy': 20,
#  'performed': 20,
#  'tissue': 20,
#  'public': 20,
#  'practice': 20,
#  'current': 20,
#  'assay': 19,
#  'lower': 19,
#  'prognostic': 19,
#  'proposed': 19,
#  'but': 19,
#  'evaluate': 19,
#  'age': 19,
#  'type': 19,
#  'systems': 19,
#  'lymph': 19,
#  'ky': 19,
#  'laboratory': 19,
#  'positive': 18,
#  'under': 18,
#  'four': 18,
#  'random': 18,
#  'there': 18,
#  'specific': 18,
#  'infection': 18,
#  'digital': 18,
#  'evaluation': 18,
#  'effects': 18,
#  'tests': 18,
#  'information': 17,
#  'auc': 17,
#  'rate': 17,
#  'changes': 17,
#  'cause': 17,
#  'present': 17,
#  'image': 17,
#  'then': 17,
#  'significantly': 17,
#  'understanding': 17,
#  'biomarkers': 17,
#  'case': 17,
#  '95%': 17,
#  'liver': 17,
#  'characteristics': 16,
#  'status': 16,
#  'included': 16,
#  'set': 16,
#  'conclusion': 16,
#  'human': 16,
#  'area': 16,
#  'some': 16,
#  'primary': 16,
#  'no': 16,
#  'each': 16,
#  'plasma': 16,
#  'concentrations': 16,
#  'key': 16,
#  'pandemic': 16,
#  'node': 16,
#  'lymphedema': 16,
#  'antibody': 16,
#  'aimed': 15,
#  'further': 15,
#  'cancers': 15,
#  'factor': 15,
#  '<': 15,
#  'who': 15,
#  'genetic': 15,
#  'average': 15,
#  'quality': 15,
#  'related': 15,
#  'selected': 15,
#  'vector': 15,
#  'protein': 15,
#  'increase': 15,
#  'years': 15,
#  'monitoring': 15,
#  'therapeutic': 15,
#  'metastasis': 15,
#  'stage': 15,
#  'importance': 14,
#  'igg': 14,
#  'findings': 14,
#  'patterns': 14,
#  'provide': 14,
#  'prognosis': 14,
#  'datasets': 14,
#  'independent': 14,
#  'validated': 14,
#  'logistic': 14,
#  'best': 14,
#  'machinelearning': 14,
#  'future': 14,
#  'dataset': 14,
#  'obtained': 14,
#  'ratio': 14,
#  'first': 14,
#  'tool': 14,
#  'through': 14,
#  'progression': 14,
#  'several': 14,
#  'variables': 14,
#  'spectrometry': 14,
#  'those': 14,
#  'rates': 14,
#  'number': 14,
#  'review': 14,
#  'multiple': 14,
#  'al': 14,
#  'better': 14,
#  'cervical': 14,
#  'metabolic': 14,
#  'electronic': 14,
#  'technologies': 14,
#  'technology': 14,
#  'denosumab': 14,
#  'endometriosis': 14,
#  'assess': 13,
#  'individual': 13,
#  'achieved': 13,
#  'birth': 13,
#  'leading': 13,
#  'radiomics': 13,
#  'help': 13,
#  'analyzed': 13,
#  'effective': 13,
#  'strategies': 13,
#  'here': 13,
#  'differences': 13,
#  'low': 13,
#  'presence': 13,
#  'being': 13,
#  'control': 13,
#  'lung': 13,
#  'known': 13,
#  'discussed': 13,
#  'incidence': 13,
#  'knowledge': 13,
#  'weight': 13,
#  'pg': 13,
#  'within': 12,
#  '(95%': 12,
#  'analyses': 12,
#  'diseases': 12,
#  'work': 12,
#  'aim': 12,
#  'observed': 12,
#  'diagnosed': 12,
#  'level': 12,
#  'confirmed': 12,
#  'novel': 12,
#  'surgery': 12,
#  'evidence': 12,
#  'types': 12,
#  'ofthe': 12,
#  'symptoms': 12,
#  'assessment': 12,
#  'trial': 12,
#  'improved': 12,
#  'software': 12,
#  'pathologists': 12,
#  'growth': 12,
#  'next': 12,
#  'provides': 12,
#  'implementation': 12,
#  'provided': 12,
#  'challenges': 12,
#  'about': 12,
#  'pain': 12,
#  'ah': 12,
#  't': 12,
#  'roche': 12,
#  'records': 12,
#  'approaches': 11,
#  'over': 11,
#  'across': 11,
#  'sources': 11,
#  'predicting': 11,
#  'challenging': 11,
#  'feature': 11,
#  'drugs': 11,
#  'carcinoma': 11,
#  'poor': 11,
#  'validate': 11,
#  'addition': 11,
#  'operating': 11,
#  'extracted': 11,
#  'outcome': 11,
#  '(ml)': 11,
#  'index': 11,
#  'critical': 11,
#  'individuals': 11,
#  'correlation': 11,
#  'against': 11,
#  'discuss': 11,
#  'population': 11,
#  'ability': 11,
#  'understand': 11,
#  '+': 11,
#  'personalized': 11,
#  'mean': 11,
#  'severity': 11,
#  'result': 11,
#  'utility': 11,
#  'rapid': 11,
#  'general': 11,
#  'diagnoses': 11,
#  'recognize': 11,
#  'pd': 11,
#  'design': 11,
#  'often': 11,
#  'increasing': 11,
#  'applications': 11,
#  'objective': 11,
#  'many': 11,
#  'hpv': 11,
#  'state': 11,
#  'targets': 11,
#  'ctdna': 11,
#  'detect': 11,
#  'melanoma': 11,
#  'tpi': 11,
#  'out': 11,
#  'luad': 11,
#  'baseline': 10,
#  'antibodies': 10,
#  'negative': 10,
#  'biological': 10,
#  'accurate': 10,
#  'contribute': 10,
#  'process': 10,
#  'paper': 10,
#  'decision': 10,
#  'gradient': 10,
#  'utilized': 10,
#  'examination': 10,
#  'respectively': 10,
#  'phase': 10,
#  'tools': 10,
#  'available': 10,
#  'purpose': 10,
#  'despite': 10,
#  'oral': 10,
#  'identifying': 10,
#  'months': 10,
#  'groups': 10,
#  'improving': 10,
#  'linear': 10,
#  'suggest': 10,
#  'polyp': 10,
#  'six': 10,
#  'standard': 10,
#  'become': 10,
#  'vaccination': 10,
#  'associations': 10,
#  'mapping': 10,
#  'demonstrated': 10,
#  'optimal': 10,
#  'estimates': 10,
#  'acute': 10,
#  'thus': 10,
#  'include': 10,
#  'gdm': 10,
#  'center': 10,
#  'school': 10,
#  'where': 10,
#  'biosafety': 10,
#  'program': 10,
#  'demand': 10,
#  'p': 10,
#  'ald': 10,
#  'm': 10,
#  'tuberculosis': 10,
#  'tb': 10,
#  'ml)': 10,
#  '-': 10,
#  'assays': 10,
#  'narcolepsy': 10,
#  'elisa': 10,
#  'np': 10,
#  'guideline': 10,
#  'host': 9,
#  'trials': 9,
#  'serum': 9,
#  'binding': 9,
#  'remains': 9,
#  'predictions': 9,
#  'scores': 9,
#  'postoperative': 9,
#  '100': 9,
#  'external': 9,
#  '(p': 9,
#  'classifier': 9,
#  'gastric': 9,
#  'normal': 9,
#  'them': 9,
#  'recurrence': 9,
#  'death': 9,
#  'environmental': 9,
#  'followed': 9,
#  'strategy': 9,
#  '2020': 9,
#  'burden': 9,
#  'via': 9,
#  'us': 9,
#  'following': 9,
#  'guidelines': 9,
#  'applied': 9,
#  'pulmonary': 9,
#  'deaths': 9,
#  'segmentation': 9,
#  'common': 9,
#  'severe': 9,
#  'quantitative': 9,
#  'collected': 9,
#  '(n': 9,
#  'established': 9,
#  'useful': 9,
#  'play': 9,
#  'department': 9,
#  'vs': 9,
#  'focus': 9,
#  'light': 9,
#  'developing': 9,
#  'designed': 9,
#  'made': 9,
#  'mechanisms': 9,
#  'postpartum': 9,
#  'phd': 9,
#  'presentation': 9,
#  'single': 9,
#  'l': 9,
#  'houston': 9,
#  'quantitation': 9,
#  'unique': 9,
#  'term': 9,
#  '287': 9,
#  'alisertib': 9,
#  'consultant': 9,
#  'complex': 9,
#  'reports': 9,
#  'omics': 9,
#  'apps': 9,
#  'topics': 9,
#  'hcc': 9,
#  'responses': 8,
#  'relative': 8,
#  'nine': 8,
#  'conducted': 8,
#  'assessed': 8,
#  'safety': 8,
#  'dose': 8,
#  'areas': 8,
#  'improvement': 8,
#  'infectious': 8,
#  'does': 8,
#  'computational': 8,
#  'derived': 8,
#  'pathways': 8,
#  'good': 8,
#  'classifiers': 8,
#  'great': 8,
#  'combined': 8,
#  'lr': 8,
#  'demonstrate': 8,
#  'ad': 8,
#  'existing': 8,
#  'limited': 8,
#  'enhanced': 8,
#  'determine': 8,
#  '(ai)': 8,
#  'lesions': 8,
#  'trained': 8,
#  'rp': 8,
#  'scientific': 8,
#  'occurrence': 8,
#  'make': 8,
#  'parameters': 8,
#  'signatures': 8,
#  'diet': 8,
#  'aims': 8,
#  'united': 8,
#  'states': 8,
#  'caused': 8,
#  'days': 8,
#  'therefore': 8,
#  'would': 8,
#  'although': 8,
#  'measures': 8,
#  'cellular': 8,
#  'appropriate': 8,
#  'platforms': 8,
#  'additional': 8,
#  'receptor': 8,
#  '2021': 8,
#  'essential': 8,
#  'define': 8,
#  'activation': 8,
#  '5': 8,
#  'fit': 8,
#  'interest': 8,
#  '100%': 8,
#  'part': 8,
#  'published': 8,
#  'stroke': 8,
#  'world': 8,
#  'rf': 8,
#  'large': 8,
#  'nodes': 8,
#  'text': 8,
#  'effectiveness': 8,
#  't2d': 8,
#  'robust': 8,
#  'prior': 8,
#  'having': 8,
#  'activityparticipants': 8,
#  'cirrhosis': 8,
#  'molecules': 8,
#  'processes': 8,
#  'proteins': 8,
#  'reported': 8,
#  'massarray': 8,
#  'diagnostics': 8,
#  'analytical': 8,
#  '&': 8,
#  'extraction': 8,
#  'igfbp-7': 8,
#  'user': 8,
#  'integration': 8,
#  'life': 8,
#  'impact': 8,
#  'recent': 8,
#  'providers': 8,
#  'et': 8,
#  'pancreatic': 8,
#  'fees': 8,
#  'mentions': 8,
#  'vaccine': 7,
#  'measured': 7,
#  'considered': 7,
#  'institute': 7,
#  'interpretation': 7,
#  'setting': 7,
#  'major': 7,
#  'society': 7,
#  'small': 7,
#  'receiver': 7,
#  'pathological': 7,
#  'might': 7,
#  'required': 7,
#  'convolutional': 7,
#  'selection': 7,
#  'experimental': 7,
#  'unsupervised': 7,
#  'reflect': 7,
#  'materials': 7,
#  'surgical': 7,
#  'still': 7,
#  'artificialintelligence': 7,
#  'making': 7,
#  'goal': 7,
#  'up': 7,
#  'radiation': 7,
#  'january': 7,
#  '6': 7,
#  'finally': 7,
#  'experience': 7,
#  'clinicians': 7,
#  'measure': 7,
#  '9': 7,
#  'intervention': 7,
#  '0001)': 7,
#  'colonoscopy': 7,
#  'ct': 7,
#  'damage': 7,
#  'literature': 7,
#  'along': 7,
#  'highest': 7,
#  'explore': 7,
#  'transmission': 7,
#  'sections': 7,
#  'slides': 7,
#  'slide': 7,
#  'tissues': 7,
#  'ec': 7,
#  'survey': 7,
#  'biomedical': 7,
#  'created': 7,
#  'period': 7,
#  'variability': 7,
#  'conditions': 7,
#  'cvd': 7,
#  'affected': 7,
#  'dl': 7,
#  'inthe': 7,
#  'predicted': 7,
#  'targeted': 7,
#  'rare': 7,
#  'scale': 7,
#  'metabolites': 7,
#  'highlight': 7,
#  'delivery': 7,
#  'variety': 7,
#  'around': 7,
#  'read': 7,
#  'diabetes': 7,
#  'routine': 7,
#  'criteria': 7,
#  'neoplasms': 7,
#  'j': 7,
#  'they': 7,
#  'panel': 7,
#  'interaction': 7,
#  'steatosis': 7,
#  'elevated': 7,
#  'vesicles': 7,
#  'tx': 7,
#  'post-primary': 7,
#  'rna': 7,
#  'slns': 7,
#  'possible': 7,
#  'csf': 7,
#  'abeta42': 7,
#  'regions': 7,
#  'urine': 7,
#  'commonly': 7,
#  'orexin-a': 7,
#  'without': 7,
#  '8': 7,
#  'hla': 7,
#  'consistently': 7,
#  'cytokines': 7,
#  'because': 7,
#  'pressure': 7,
#  'follow-up': 7,
#  'skin': 7,
#  'wearing': 7,
#  'covrnn': 7,
#  'private': 7,
#  'board': 7,
#  'gedeon': 7,
#  'arsenic': 7,
#  'identification': 6,
#  'measurements': 6,
#  'estimated': 6,
#  'versus': 6,
#  'weeks': 6,
#  'variable': 6,
#  'collection': 6,
#  'predictors': 6,
#  'funding': 6,
#  'national': 6,
#  'any': 6,
#  'towards': 6,
#  'usage': 6,
#  'worldwide': 6,
#  'boosting': 6,
#  'malignant': 6,
#  'efficient': 6,
#  'mvi': 6,
#  'hospitals': 6,
#  'presented': 6,
#  'nomogram': 6,
#  '(auc)': 6,
#  'andthe': 6,
#  'b': 6,
#  'exhibited': 6,
#  'cohorts': 6,
#  'erna': 6,
#  'machine-learning': 6,
#  'subtypes': 6,
#  'gc': 6,
#  'indicators': 6,
#  'revealed': 6,
#  'biomarker': 6,
#  'currently': 6,
#  'recently': 6,
#  'efforts': 6,
#  'very': 6,
#  'experiments': 6,
#  'theclinical': 6,
#  'rating': 6,
#  'detecting': 6,
#  'field': 6,
#  'meningiomas': 6,
#  'grade': 6,
#  'randomly': 6,
#  '7': 6,
#  'distinguish': 6,
#  'coefficient': 6,
#  'accurately': 6,
#  "patients'": 6,
#  'last': 6,
#  'habits': 6,
#  'emerging': 6,
#  'relevant': 6,
#  'given': 6,
#  'advanced': 6,
#  'few': 6,
#  'female': 6,
#  'correlated': 6,
#  'hub': 6,
#  'basis': 6,
#  '2019': 6,
#  '1000': 6,
#  'distinct': 6,
#  '4': 6,
#  'investigated': 6,
#  'mediterranean': 6,
#  'particularly': 6,
#  'whereas': 6,
#  'q': 6,
#  'characteristic': 6,
#  'larger': 6,
#  'surveillance': 6,
#  'european': 6,
#  'ovarian': 6,
#  'least': 6,
#  'virus': 6,
#  'traditional': 6,
#  'long': 6,
#  'volume': 6,
#  'remission': 6,
#  'signaling': 6,
#  'candidate': 6,
#  'greater': 6,
#  'social': 6,
#  'visual': 6,
#  'opportunities': 6,
#  'structures': 6,
#  'alterations': 6,
#  'providing': 6,
#  'stages': 6,
#  'discovery': 6,
#  'therapies': 6,
#  'riskfactors': 6,
#  'dce-mri': 6,
#  'indicated': 6,
#  'processing': 6,
#  'achieve': 6,
#  'original': 6,
#  'powerful': 6,
#  'biopsy': 6,
#  'generated': 6,
#  'stils': 6,
#  'per': 6,
#  'lungs': 6,
#  'previously': 6,
#  'treatments': 6,
#  'characterized': 6,
#  'modeling': 6,
#  'cardiovascular': 6,
#  'causes': 6,
#  'programs': 6,
#  'forecasting': 6,
#  'estimate': 6,
#  'svm': 6,
#  'site': 6,
#  'broad': 6,
#  'range': 6,
#  'show': 6,
#  'gestational': 6,
#  'enable': 6,
#  'interventions': 6,
#  'probability': 6,
#  'product': 6,
#  'academic': 6,
#  'basic': 6,
#  'college': 6,
#  'record': 6,
#  'in-hospital': 6,
#  'duration': 6,
#  'em': 6,
#  'steatohepatitis': 6,
#  'beable': 6,
#  'alcohol-associated': 6,
#  'warner': 6,
#  'lipid': 6,
#  'loss': 6,
#  'context': 6,
#  'mutation': 6,
#  'needs': 6,
#  'sequencing': 6,
#  'single-cell': 6,
#  'cost': 6,
#  '20': 6,
#  'abnormal': 6,
#  'consulting': 6,
#  'database': 6,
#  'less': 6,
#  'zikv': 6,
#  'science': 6,
#  'healthy': 6,
#  'he': 6,
#  'automated': 6,
#  'gbm': 6,
#  'siemens': 6,
#  'questionnaire': 6,
#  'sarcomas': 6,
#  'sarcoma': 6,
#  'agonal-stress': 6,
#  'tem': 6,
#  'chordoma': 6,
#  'histology': 6,
#  'allow': 6,
#  'satisfaction': 6,
#  'hypoxia': 6,
#  'adm': 6,
#  'hba1c': 6,
#  'mask': 6,
#  'policy': 6,
#  'ferroptosis-related': 6,
#  'psa': 6,
#  'sre': 6,
#  'discontinuation': 6,
#  'grants': 6,
#  'richter': 6,
#  'merck': 6,
#  'sa': 6,
#  'hiv-1': 5,
#  'availability': 5,
#  'highly': 5,
#  'studied': 5,
#  'enhance': 5,
#  'statistical': 5,
#  'authors': 5,
#  'guide': 5,
#  'propose': 5,
#  'pathway': 5,
#  'challenge': 5,
#  'tree': 5,
#  'resonance': 5,
#  'calibration': 5,
#  'conventional': 5,
#  'comprehensive': 5,
#  'regulation': 5,
#  'constructed': 5,
#  'sers': 5,
#  'combination': 5,
#  'main': 5,
#  'target': 5,
#  'framework': 5,
#  'templates': 5,
#  'previous': 5,
#  'low-grade': 5,
#  'patientswith': 5,
#  'received': 5,
#  'meningioma': 5,
#  'shown': 5,
#  'heterogeneity': 5,
#  'lifestyle': 5,
#  'smoking': 5,
#  'lesion': 5,
#  'architectures': 5,
#  'group)': 5,
#  'build': 5,
#  'facilitate': 5,
#  'crucial': 5,
#  'change': 5,
#  'bc': 5,
#  'toidentify': 5,
#  'supervised': 5,
#  'wasassociated': 5,
#  'adducts': 5,
#  'controls': 5,
#  'find': 5,
#  'ensemble': 5,
#  '40': 5,
#  'intestinal': 5,
#  'decreased': 5,
#  'mechanistic': 5,
#  'registered': 5,
#  '(ie': 5,
#  '13%': 5,
#  'mixed': 5,
#  'performances': 5,
#  'mlp': 5,
#  'vascular': 5,
#  'report': 5,
#  'tomography': 5,
#  'speed': 5,
#  'morbidity': 5,
#  'withthe': 5,
#  'screened': 5,
#  'end': 5,
#  'vaccines': 5,
#  'topredict': 5,
#  'numbers': 5,
#  'icu': 5,
#  'reduce': 5,
#  'remain': 5,
#  'density': 5,
#  'options': 5,
#  'quantify': 5,
#  'proteomic': 5,
#  'way': 5,
#  'apply': 5,
#  'shows': 5,
#  ...}

# %%
# try to remove the most common english words
dfs = pd.read_html('https://en.wikipedia.org/wiki/Most_common_words_in_English')

# %%
common_worlds = dfs[0]['Word'].tolist()

# %%
cleaned_dict = dic.copy()

for key, value in dic.items():
    if key in common_worlds:
        del cleaned_dict[key]

# %%
# still a lot of trash
# need other method to clean it better otherwise not useful
cleaned_dict
# Out:
# {'is': 217,
#  'were': 211,
#  'was': 184,
#  'cancer': 175,
#  'patients': 159,
#  'are': 136,
#  'model': 125,
#  'data': 118,
#  'learning': 113,
#  'clinical': 103,
#  'study': 101,
#  'machine': 95,
#  'results': 90,
#  'using': 89,
#  'models': 89,
#  'methods': 76,
#  'risk': 74,
#  'based': 67,
#  'covid-19': 61,
#  'used': 60,
#  'treatment': 60,
#  'has': 58,
#  'health': 58,
#  'prediction': 57,
#  'diagnosis': 56,
#  'analysis': 56,
#  'detection': 55,
#  '1': 54,
#  'between': 54,
#  'disease': 53,
#  'may': 50,
#  'been': 47,
#  'identify': 46,
#  'accuracy': 45,
#  'genes': 45,
#  'research': 44,
#  'patient': 43,
#  'upon': 43,
#  'should': 41,
#  'early': 41,
#  'prevention': 41,
#  'participants': 40,
#  'more': 40,
#  'ai': 40,
#  'able': 40,
#  'features': 39,
#  'had': 39,
#  'testing': 39,
#  '2': 39,
#  'care': 38,
#  'activity': 38,
#  'completion': 38,
#  'performance': 37,
#  'such': 37,
#  'system': 37,
#  'tumor': 36,
#  'potential': 36,
#  'ml': 36,
#  'showed': 35,
#  'high': 34,
#  '=': 34,
#  'associated': 34,
#  'mortality': 34,
#  'improve': 33,
#  'support': 33,
#  'survival': 33,
#  'medicine': 33,
#  'university': 33,
#  'both': 32,
#  'studies': 32,
#  'breast': 32,
#  'role': 32,
#  'validation': 32,
#  'method': 32,
#  'factors': 32,
#  'cells': 32,
#  'sensitivity': 31,
#  'imaging': 31,
#  'however': 31,
#  'images': 30,
#  'group': 30,
#  'development': 30,
#  'background': 29,
#  'response': 29,
#  'including': 29,
#  'identified': 29,
#  'hospital': 29,
#  'specificity': 29,
#  'screening': 29,
#  'network': 28,
#  'pathology': 28,
#  '3': 28,
#  'cases': 28,
#  'ci': 27,
#  'cell': 27,
#  'samples': 27,
#  'algorithm': 27,
#  'algorithms': 27,
#  'sars-cov-2': 27,
#  'louisville': 27,
#  'outcomes': 26,
#  'total': 26,
#  'blood': 26,
#  'women': 25,
#  'develop': 25,
#  'expression': 25,
#  'found': 25,
#  'intelligence': 25,
#  'need': 25,
#  'levels': 25,
#  'curve': 24,
#  'diagnostic': 24,
#  'techniques': 24,
#  'training': 24,
#  'while': 24,
#  'management': 24,
#  'higher': 23,
#  'drug': 23,
#  'developed': 23,
#  'regression': 23,
#  'predictive': 23,
#  'neural': 23,
#  'test': 23,
#  'conclusions': 23,
#  'during': 23,
#  'gene': 23,
#  'describe': 23,
#  'immune': 22,
#  'three': 22,
#  'significant': 22,
#  'molecular': 22,
#  'score': 22,
#  'increased': 22,
#  'evaluated': 22,
#  'different': 22,
#  'artificial': 22,
#  'medical': 22,
#  'deep': 22,
#  'application': 22,
#  'various': 22,
#  'approach': 21,
#  'precision': 21,
#  'important': 21,
#  'compared': 21,
#  'effect': 21,
#  'predict': 21,
#  'mass': 21,
#  'healthcare': 21,
#  'due': 21,
#  'among': 20,
#  'overall': 20,
#  'classification': 20,
#  'tumors': 20,
#  'forest': 20,
#  'cohort': 20,
#  'value': 20,
#  'therapy': 20,
#  'performed': 20,
#  'tissue': 20,
#  'public': 20,
#  'practice': 20,
#  'current': 20,
#  'assay': 19,
#  'lower': 19,
#  'prognostic': 19,
#  'proposed': 19,
#  'evaluate': 19,
#  'age': 19,
#  'type': 19,
#  'systems': 19,
#  'lymph': 19,
#  'ky': 19,
#  'laboratory': 19,
#  'positive': 18,
#  'under': 18,
#  'four': 18,
#  'random': 18,
#  'specific': 18,
#  'infection': 18,
#  'digital': 18,
#  'evaluation': 18,
#  'effects': 18,
#  'tests': 18,
#  'information': 17,
#  'auc': 17,
#  'rate': 17,
#  'changes': 17,
#  'cause': 17,
#  'present': 17,
#  'image': 17,
#  'significantly': 17,
#  'understanding': 17,
#  'biomarkers': 17,
#  'case': 17,
#  '95%': 17,
#  'liver': 17,
#  'characteristics': 16,
#  'status': 16,
#  'included': 16,
#  'set': 16,
#  'conclusion': 16,
#  'human': 16,
#  'area': 16,
#  'primary': 16,
#  'each': 16,
#  'plasma': 16,
#  'concentrations': 16,
#  'key': 16,
#  'pandemic': 16,
#  'node': 16,
#  'lymphedema': 16,
#  'antibody': 16,
#  'aimed': 15,
#  'further': 15,
#  'cancers': 15,
#  'factor': 15,
#  '<': 15,
#  'genetic': 15,
#  'average': 15,
#  'quality': 15,
#  'related': 15,
#  'selected': 15,
#  'vector': 15,
#  'protein': 15,
#  'increase': 15,
#  'years': 15,
#  'monitoring': 15,
#  'therapeutic': 15,
#  'metastasis': 15,
#  'stage': 15,
#  'importance': 14,
#  'igg': 14,
#  'findings': 14,
#  'patterns': 14,
#  'provide': 14,
#  'prognosis': 14,
#  'datasets': 14,
#  'independent': 14,
#  'validated': 14,
#  'logistic': 14,
#  'best': 14,
#  'machinelearning': 14,
#  'future': 14,
#  'dataset': 14,
#  'obtained': 14,
#  'ratio': 14,
#  'tool': 14,
#  'through': 14,
#  'progression': 14,
#  'several': 14,
#  'variables': 14,
#  'spectrometry': 14,
#  'those': 14,
#  'rates': 14,
#  'number': 14,
#  'review': 14,
#  'multiple': 14,
#  'al': 14,
#  'better': 14,
#  'cervical': 14,
#  'metabolic': 14,
#  'electronic': 14,
#  'technologies': 14,
#  'technology': 14,
#  'denosumab': 14,
#  'endometriosis': 14,
#  'assess': 13,
#  'individual': 13,
#  'achieved': 13,
#  'birth': 13,
#  'leading': 13,
#  'radiomics': 13,
#  'help': 13,
#  'analyzed': 13,
#  'effective': 13,
#  'strategies': 13,
#  'here': 13,
#  'differences': 13,
#  'low': 13,
#  'presence': 13,
#  'being': 13,
#  'control': 13,
#  'lung': 13,
#  'known': 13,
#  'discussed': 13,
#  'incidence': 13,
#  'knowledge': 13,
#  'weight': 13,
#  'pg': 13,
#  'within': 12,
#  '(95%': 12,
#  'analyses': 12,
#  'diseases': 12,
#  'aim': 12,
#  'observed': 12,
#  'diagnosed': 12,
#  'level': 12,
#  'confirmed': 12,
#  'novel': 12,
#  'surgery': 12,
#  'evidence': 12,
#  'types': 12,
#  'ofthe': 12,
#  'symptoms': 12,
#  'assessment': 12,
#  'trial': 12,
#  'improved': 12,
#  'software': 12,
#  'pathologists': 12,
#  'growth': 12,
#  'next': 12,
#  'provides': 12,
#  'implementation': 12,
#  'provided': 12,
#  'challenges': 12,
#  'pain': 12,
#  'ah': 12,
#  't': 12,
#  'roche': 12,
#  'records': 12,
#  'approaches': 11,
#  'across': 11,
#  'sources': 11,
#  'predicting': 11,
#  'challenging': 11,
#  'feature': 11,
#  'drugs': 11,
#  'carcinoma': 11,
#  'poor': 11,
#  'validate': 11,
#  'addition': 11,
#  'operating': 11,
#  'extracted': 11,
#  'outcome': 11,
#  '(ml)': 11,
#  'index': 11,
#  'critical': 11,
#  'individuals': 11,
#  'correlation': 11,
#  'against': 11,
#  'discuss': 11,
#  'population': 11,
#  'ability': 11,
#  'understand': 11,
#  '+': 11,
#  'personalized': 11,
#  'mean': 11,
#  'severity': 11,
#  'result': 11,
#  'utility': 11,
#  'rapid': 11,
#  'general': 11,
#  'diagnoses': 11,
#  'recognize': 11,
#  'pd': 11,
#  'design': 11,
#  'often': 11,
#  'increasing': 11,
#  'applications': 11,
#  'objective': 11,
#  'many': 11,
#  'hpv': 11,
#  'state': 11,
#  'targets': 11,
#  'ctdna': 11,
#  'detect': 11,
#  'melanoma': 11,
#  'tpi': 11,
#  'luad': 11,
#  'baseline': 10,
#  'antibodies': 10,
#  'negative': 10,
#  'biological': 10,
#  'accurate': 10,
#  'contribute': 10,
#  'process': 10,
#  'paper': 10,
#  'decision': 10,
#  'gradient': 10,
#  'utilized': 10,
#  'examination': 10,
#  'respectively': 10,
#  'phase': 10,
#  'tools': 10,
#  'available': 10,
#  'purpose': 10,
#  'despite': 10,
#  'oral': 10,
#  'identifying': 10,
#  'months': 10,
#  'groups': 10,
#  'improving': 10,
#  'linear': 10,
#  'suggest': 10,
#  'polyp': 10,
#  'six': 10,
#  'standard': 10,
#  'become': 10,
#  'vaccination': 10,
#  'associations': 10,
#  'mapping': 10,
#  'demonstrated': 10,
#  'optimal': 10,
#  'estimates': 10,
#  'acute': 10,
#  'thus': 10,
#  'include': 10,
#  'gdm': 10,
#  'center': 10,
#  'school': 10,
#  'where': 10,
#  'biosafety': 10,
#  'program': 10,
#  'demand': 10,
#  'p': 10,
#  'ald': 10,
#  'm': 10,
#  'tuberculosis': 10,
#  'tb': 10,
#  'ml)': 10,
#  '-': 10,
#  'assays': 10,
#  'narcolepsy': 10,
#  'elisa': 10,
#  'np': 10,
#  'guideline': 10,
#  'host': 9,
#  'trials': 9,
#  'serum': 9,
#  'binding': 9,
#  'remains': 9,
#  'predictions': 9,
#  'scores': 9,
#  'postoperative': 9,
#  '100': 9,
#  'external': 9,
#  '(p': 9,
#  'classifier': 9,
#  'gastric': 9,
#  'normal': 9,
#  'recurrence': 9,
#  'death': 9,
#  'environmental': 9,
#  'followed': 9,
#  'strategy': 9,
#  '2020': 9,
#  'burden': 9,
#  'via': 9,
#  'following': 9,
#  'guidelines': 9,
#  'applied': 9,
#  'pulmonary': 9,
#  'deaths': 9,
#  'segmentation': 9,
#  'common': 9,
#  'severe': 9,
#  'quantitative': 9,
#  'collected': 9,
#  '(n': 9,
#  'established': 9,
#  'useful': 9,
#  'play': 9,
#  'department': 9,
#  'vs': 9,
#  'focus': 9,
#  'light': 9,
#  'developing': 9,
#  'designed': 9,
#  'made': 9,
#  'mechanisms': 9,
#  'postpartum': 9,
#  'phd': 9,
#  'presentation': 9,
#  'single': 9,
#  'l': 9,
#  'houston': 9,
#  'quantitation': 9,
#  'unique': 9,
#  'term': 9,
#  '287': 9,
#  'alisertib': 9,
#  'consultant': 9,
#  'complex': 9,
#  'reports': 9,
#  'omics': 9,
#  'apps': 9,
#  'topics': 9,
#  'hcc': 9,
#  'responses': 8,
#  'relative': 8,
#  'nine': 8,
#  'conducted': 8,
#  'assessed': 8,
#  'safety': 8,
#  'dose': 8,
#  'areas': 8,
#  'improvement': 8,
#  'infectious': 8,
#  'does': 8,
#  'computational': 8,
#  'derived': 8,
#  'pathways': 8,
#  'classifiers': 8,
#  'great': 8,
#  'combined': 8,
#  'lr': 8,
#  'demonstrate': 8,
#  'ad': 8,
#  'existing': 8,
#  'limited': 8,
#  'enhanced': 8,
#  'determine': 8,
#  '(ai)': 8,
#  'lesions': 8,
#  'trained': 8,
#  'rp': 8,
#  'scientific': 8,
#  'occurrence': 8,
#  'parameters': 8,
#  'signatures': 8,
#  'diet': 8,
#  'aims': 8,
#  'united': 8,
#  'states': 8,
#  'caused': 8,
#  'days': 8,
#  'therefore': 8,
#  'although': 8,
#  'measures': 8,
#  'cellular': 8,
#  'appropriate': 8,
#  'platforms': 8,
#  'additional': 8,
#  'receptor': 8,
#  '2021': 8,
#  'essential': 8,
#  'define': 8,
#  'activation': 8,
#  '5': 8,
#  'fit': 8,
#  'interest': 8,
#  '100%': 8,
#  'part': 8,
#  'published': 8,
#  'stroke': 8,
#  'world': 8,
#  'rf': 8,
#  'large': 8,
#  'nodes': 8,
#  'text': 8,
#  'effectiveness': 8,
#  't2d': 8,
#  'robust': 8,
#  'prior': 8,
#  'having': 8,
#  'activityparticipants': 8,
#  'cirrhosis': 8,
#  'molecules': 8,
#  'processes': 8,
#  'proteins': 8,
#  'reported': 8,
#  'massarray': 8,
#  'diagnostics': 8,
#  'analytical': 8,
#  '&': 8,
#  'extraction': 8,
#  'igfbp-7': 8,
#  'user': 8,
#  'integration': 8,
#  'life': 8,
#  'impact': 8,
#  'recent': 8,
#  'providers': 8,
#  'et': 8,
#  'pancreatic': 8,
#  'fees': 8,
#  'mentions': 8,
#  'vaccine': 7,
#  'measured': 7,
#  'considered': 7,
#  'institute': 7,
#  'interpretation': 7,
#  'setting': 7,
#  'major': 7,
#  'society': 7,
#  'small': 7,
#  'receiver': 7,
#  'pathological': 7,
#  'might': 7,
#  'required': 7,
#  'convolutional': 7,
#  'selection': 7,
#  'experimental': 7,
#  'unsupervised': 7,
#  'reflect': 7,
#  'materials': 7,
#  'surgical': 7,
#  'still': 7,
#  'artificialintelligence': 7,
#  'making': 7,
#  'goal': 7,
#  'radiation': 7,
#  'january': 7,
#  '6': 7,
#  'finally': 7,
#  'experience': 7,
#  'clinicians': 7,
#  'measure': 7,
#  '9': 7,
#  'intervention': 7,
#  '0001)': 7,
#  'colonoscopy': 7,
#  'ct': 7,
#  'damage': 7,
#  'literature': 7,
#  'along': 7,
#  'highest': 7,
#  'explore': 7,
#  'transmission': 7,
#  'sections': 7,
#  'slides': 7,
#  'slide': 7,
#  'tissues': 7,
#  'ec': 7,
#  'survey': 7,
#  'biomedical': 7,
#  'created': 7,
#  'period': 7,
#  'variability': 7,
#  'conditions': 7,
#  'cvd': 7,
#  'affected': 7,
#  'dl': 7,
#  'inthe': 7,
#  'predicted': 7,
#  'targeted': 7,
#  'rare': 7,
#  'scale': 7,
#  'metabolites': 7,
#  'highlight': 7,
#  'delivery': 7,
#  'variety': 7,
#  'around': 7,
#  'read': 7,
#  'diabetes': 7,
#  'routine': 7,
#  'criteria': 7,
#  'neoplasms': 7,
#  'j': 7,
#  'panel': 7,
#  'interaction': 7,
#  'steatosis': 7,
#  'elevated': 7,
#  'vesicles': 7,
#  'tx': 7,
#  'post-primary': 7,
#  'rna': 7,
#  'slns': 7,
#  'possible': 7,
#  'csf': 7,
#  'abeta42': 7,
#  'regions': 7,
#  'urine': 7,
#  'commonly': 7,
#  'orexin-a': 7,
#  'without': 7,
#  '8': 7,
#  'hla': 7,
#  'consistently': 7,
#  'cytokines': 7,
#  'pressure': 7,
#  'follow-up': 7,
#  'skin': 7,
#  'wearing': 7,
#  'covrnn': 7,
#  'private': 7,
#  'board': 7,
#  'gedeon': 7,
#  'arsenic': 7,
#  'identification': 6,
#  'measurements': 6,
#  'estimated': 6,
#  'versus': 6,
#  'weeks': 6,
#  'variable': 6,
#  'collection': 6,
#  'predictors': 6,
#  'funding': 6,
#  'national': 6,
#  'towards': 6,
#  'usage': 6,
#  'worldwide': 6,
#  'boosting': 6,
#  'malignant': 6,
#  'efficient': 6,
#  'mvi': 6,
#  'hospitals': 6,
#  'presented': 6,
#  'nomogram': 6,
#  '(auc)': 6,
#  'andthe': 6,
#  'b': 6,
#  'exhibited': 6,
#  'cohorts': 6,
#  'erna': 6,
#  'machine-learning': 6,
#  'subtypes': 6,
#  'gc': 6,
#  'indicators': 6,
#  'revealed': 6,
#  'biomarker': 6,
#  'currently': 6,
#  'recently': 6,
#  'efforts': 6,
#  'very': 6,
#  'experiments': 6,
#  'theclinical': 6,
#  'rating': 6,
#  'detecting': 6,
#  'field': 6,
#  'meningiomas': 6,
#  'grade': 6,
#  'randomly': 6,
#  '7': 6,
#  'distinguish': 6,
#  'coefficient': 6,
#  'accurately': 6,
#  "patients'": 6,
#  'last': 6,
#  'habits': 6,
#  'emerging': 6,
#  'relevant': 6,
#  'given': 6,
#  'advanced': 6,
#  'few': 6,
#  'female': 6,
#  'correlated': 6,
#  'hub': 6,
#  'basis': 6,
#  '2019': 6,
#  '1000': 6,
#  'distinct': 6,
#  '4': 6,
#  'investigated': 6,
#  'mediterranean': 6,
#  'particularly': 6,
#  'whereas': 6,
#  'q': 6,
#  'characteristic': 6,
#  'larger': 6,
#  'surveillance': 6,
#  'european': 6,
#  'ovarian': 6,
#  'least': 6,
#  'virus': 6,
#  'traditional': 6,
#  'long': 6,
#  'volume': 6,
#  'remission': 6,
#  'signaling': 6,
#  'candidate': 6,
#  'greater': 6,
#  'social': 6,
#  'visual': 6,
#  'opportunities': 6,
#  'structures': 6,
#  'alterations': 6,
#  'providing': 6,
#  'stages': 6,
#  'discovery': 6,
#  'therapies': 6,
#  'riskfactors': 6,
#  'dce-mri': 6,
#  'indicated': 6,
#  'processing': 6,
#  'achieve': 6,
#  'original': 6,
#  'powerful': 6,
#  'biopsy': 6,
#  'generated': 6,
#  'stils': 6,
#  'per': 6,
#  'lungs': 6,
#  'previously': 6,
#  'treatments': 6,
#  'characterized': 6,
#  'modeling': 6,
#  'cardiovascular': 6,
#  'causes': 6,
#  'programs': 6,
#  'forecasting': 6,
#  'estimate': 6,
#  'svm': 6,
#  'site': 6,
#  'broad': 6,
#  'range': 6,
#  'show': 6,
#  'gestational': 6,
#  'enable': 6,
#  'interventions': 6,
#  'probability': 6,
#  'product': 6,
#  'academic': 6,
#  'basic': 6,
#  'college': 6,
#  'record': 6,
#  'in-hospital': 6,
#  'duration': 6,
#  'em': 6,
#  'steatohepatitis': 6,
#  'beable': 6,
#  'alcohol-associated': 6,
#  'warner': 6,
#  'lipid': 6,
#  'loss': 6,
#  'context': 6,
#  'mutation': 6,
#  'needs': 6,
#  'sequencing': 6,
#  'single-cell': 6,
#  'cost': 6,
#  '20': 6,
#  'abnormal': 6,
#  'consulting': 6,
#  'database': 6,
#  'less': 6,
#  'zikv': 6,
#  'science': 6,
#  'healthy': 6,
#  'automated': 6,
#  'gbm': 6,
#  'siemens': 6,
#  'questionnaire': 6,
#  'sarcomas': 6,
#  'sarcoma': 6,
#  'agonal-stress': 6,
#  'tem': 6,
#  'chordoma': 6,
#  'histology': 6,
#  'allow': 6,
#  'satisfaction': 6,
#  'hypoxia': 6,
#  'adm': 6,
#  'hba1c': 6,
#  'mask': 6,
#  'policy': 6,
#  'ferroptosis-related': 6,
#  'psa': 6,
#  'sre': 6,
#  'discontinuation': 6,
#  'grants': 6,
#  'richter': 6,
#  'merck': 6,
#  'sa': 6,
#  'hiv-1': 5,
#  'availability': 5,
#  'highly': 5,
#  'studied': 5,
#  'enhance': 5,
#  'statistical': 5,
#  'authors': 5,
#  'guide': 5,
#  'propose': 5,
#  'pathway': 5,
#  'challenge': 5,
#  'tree': 5,
#  'resonance': 5,
#  'calibration': 5,
#  'conventional': 5,
#  'comprehensive': 5,
#  'regulation': 5,
#  'constructed': 5,
#  'sers': 5,
#  'combination': 5,
#  'main': 5,
#  'target': 5,
#  'framework': 5,
#  'templates': 5,
#  'previous': 5,
#  'low-grade': 5,
#  'patientswith': 5,
#  'received': 5,
#  'meningioma': 5,
#  'shown': 5,
#  'heterogeneity': 5,
#  'lifestyle': 5,
#  'smoking': 5,
#  'lesion': 5,
#  'architectures': 5,
#  'group)': 5,
#  'build': 5,
#  'facilitate': 5,
#  'crucial': 5,
#  'change': 5,
#  'bc': 5,
#  'toidentify': 5,
#  'supervised': 5,
#  'wasassociated': 5,
#  'adducts': 5,
#  'controls': 5,
#  'find': 5,
#  'ensemble': 5,
#  '40': 5,
#  'intestinal': 5,
#  'decreased': 5,
#  'mechanistic': 5,
#  'registered': 5,
#  '(ie': 5,
#  '13%': 5,
#  'mixed': 5,
#  'performances': 5,
#  'mlp': 5,
#  'vascular': 5,
#  'report': 5,
#  'tomography': 5,
#  'speed': 5,
#  'morbidity': 5,
#  'withthe': 5,
#  'screened': 5,
#  'end': 5,
#  'vaccines': 5,
#  'topredict': 5,
#  'numbers': 5,
#  'icu': 5,
#  'reduce': 5,
#  'remain': 5,
#  'density': 5,
#  'options': 5,
#  'quantify': 5,
#  'proteomic': 5,
#  'apply': 5,
#  'shows': 5,
#  'growing': 5,
#  'investigate': 5,
#  'indicate': 5,
#  'cycle': 5,
#  '(p-value': 5,
#  'rapidly': 5,
#  'high-risk': 5,
#  '90%': 5,
#  'object': 5,
#  'task': 5,
#  'alone': 5,
#  'necessary': 5,
#  'pathologist': 5,
#  'pe': 5,
#  'ranging': 5,
#  'disorders': 5,
#  'carcinogenesis': 5,
#  'dna': 5,
#  'qualitative': 5,
#  'consistent': 5,
#  'expensive': 5,
#  'stratification': 5,
#  'environment': 5,
#  'recommendations': 5,
#  'search': 5,
#  'needed': 5,
#  'decrease': 5,
#  'interactions': 5,
#  'since': 5,
#  'article': 5,
#  'prevalence': 5,
#  'affecting': 5,
#  'online': 5,
#  'lack': 5,
#  'questions': 5,
#  'awareness': 5,
#  'perform': 5,
#  'same': 5,
#  'built': 5,
#  'catboost': 5,
#  'international': 5,
#  'profile': 5,
#  'containing': 5,
#  'laboratories': 5,
#  'committee': 5,
#  'compliance': 5,
#  'shorter': 5,
#  'cyp2d6': 5,
#  'inhibitor': 5,
#  'organs': 5,
#  'hepatic': 5,
#  'involved': 5,
#  'size': 5,
#  'microscopy': 5,
#  'cytometry': 5,
#  'ofthis': 5,
#  'generation': 5,
#  'explain': 5,
#  'increasingly': 5,
#  'involving': 5,
#  'utilization': 5,
#  'global': 5,
#  'compare': 5,
#  'includes': 5,
#  'additionally': 5,
#  'differentiation': 5,
#  'zika': 5,
#  'frequently': 5,
#  ...}

# %% [markdown]
# <a id='section_id5'></a>

# %% [markdown]
# # Automatic dictionary from keywords

# %%
abstracts = df['keywords'].tolist()
dic = {}
for abstract in abstracts:
    dic = word_freq(abstract, dic)
    
dic = {key: val for key, 
       val in sorted(dic.items(), 
       key = lambda ele: ele[1], reverse = True)}

# %%
dic
# Out:
# {'learning': 87,
#  'machine': 73,
#  'humans': 54,
#  'diagnosis': 37,
#  'neoplasms': 36,
#  'cancer': 31,
#  'imaging': 25,
#  'methods': 25,
#  'covid-19': 20,
#  'genetics': 19,
#  'diagnostic': 19,
#  'of': 19,
#  'health': 19,
#  'deep': 18,
#  'pathology': 17,
#  'female': 16,
#  'artificial': 16,
#  'epidemiology': 16,
#  'prevention': 16,
#  'studies': 15,
#  'intelligence': 15,
#  'control': 15,
#  'breast': 14,
#  'therapy': 14,
#  'care': 13,
#  '&': 13,
#  'algorithms': 12,
#  'carcinoma': 11,
#  'and': 11,
#  'drug': 10,
#  'neural': 10,
#  'analysis': 10,
#  'risk': 10,
#  'cell': 9,
#  'retrospective': 9,
#  'etiology': 9,
#  'prediction': 9,
#  'liver': 8,
#  'disease': 8,
#  'model': 8,
#  'detection': 8,
#  'early': 7,
#  'networks': 7,
#  'processing': 7,
#  'lung': 7,
#  'mass': 7,
#  'cervical': 7,
#  'vaccines': 7,
#  'the': 6,
#  'modeling': 6,
#  'diabetes': 6,
#  'hepatocellular': 5,
#  'biomarkers': 5,
#  'computer': 5,
#  'models': 5,
#  'network': 5,
#  'complications': 5,
#  'nutrition': 5,
#  'precision': 5,
#  'image': 5,
#  'computer-assisted': 5,
#  'factors': 5,
#  'sars-cov-2': 5,
#  'screening': 5,
#  'feature': 5,
#  'public': 5,
#  'agents': 5,
#  'forecasting': 5,
#  'medicine': 5,
#  'water': 5,
#  'vaccine': 4,
#  'surgery': 4,
#  'magnetic': 4,
#  'resonance': 4,
#  'radiomics': 4,
#  'biology': 4,
#  'oncology': 4,
#  'support': 4,
#  'vector': 4,
#  'personalized': 4,
#  'classification': 4,
#  'computed': 4,
#  'tomography': 4,
#  'computational': 4,
#  'digital': 4,
#  'effects': 4,
#  'papillomavirus': 4,
#  'infections': 4,
#  'uterine': 4,
#  'rna': 4,
#  'viral': 4,
#  'therapeutic': 4,
#  'antineoplastic': 4,
#  'adenocarcinoma': 4,
#  'prognosis': 4,
#  'treatment': 4,
#  'birth': 4,
#  'cirrhosis': 4,
#  'tumor': 3,
#  'biological': 3,
#  'systems': 3,
#  'raman': 3,
#  'mortality': 3,
#  'oral': 3,
#  'pelvic': 3,
#  'computer-aided': 3,
#  'coronavirus': 3,
#  'area': 3,
#  'under': 3,
#  'receiver': 3,
#  'operating': 3,
#  'curve': 3,
#  '2': 3,
#  'vaccination': 3,
#  'virus': 3,
#  'colonoscopy': 3,
#  'data': 3,
#  'adverse': 3,
#  'stomach': 3,
#  'index': 3,
#  'lymphatic': 3,
#  'metastasis': 3,
#  'metabolomics': 3,
#  'lymphedema': 3,
#  'use': 3,
#  'management': 3,
#  'gestational': 3,
#  'mellitus': 3,
#  'antibodies': 3,
#  'chronic': 3,
#  'gene': 3,
#  'policy': 3,
#  'medical': 3,
#  'home': 3,
#  'electronic': 3,
#  'united': 3,
#  'states': 3,
#  'spectrometry': 3,
#  'heterogeneity': 2,
#  'line': 2,
#  'media': 2,
#  'gadolinium': 2,
#  'bioinformatics': 2,
#  'reproducibility': 2,
#  'results': 2,
#  'spectroscopy': 2,
#  'synthetic': 2,
#  'chemical': 2,
#  'cluster': 2,
#  'squamous': 2,
#  'bayes': 2,
#  'theorem': 2,
#  'radiotherapy': 2,
#  'proctitis': 2,
#  'radiation': 2,
#  'depression': 2,
#  'acids': 2,
#  'ovarian': 2,
#  'pulmonary': 2,
#  'x-ray': 2,
#  'gastric': 2,
#  'auc': 2,
#  'characteristic': 2,
#  'for': 2,
#  'respiratory': 2,
#  'algorithm': 2,
#  'severity': 2,
#  'polyps': 2,
#  'colorectal': 2,
#  'polyp': 2,
#  'anastomotic': 2,
#  'reader': 2,
#  'animals': 2,
#  'diaphragmatic': 2,
#  'congenital': 2,
#  'database': 2,
#  'esophageal': 2,
#  'assessment': 2,
#  'drainage': 2,
#  'meningitis': 2,
#  'supervised': 2,
#  'diseases': 2,
#  'lymph': 2,
#  'sensitivity': 2,
#  'specificity': 2,
#  'pandemics': 2,
#  'knowledge': 2,
#  'attitudes': 2,
#  'practice': 2,
#  'papillomaviridae': 2,
#  'patient': 2,
#  'hpv': 2,
#  'asian': 2,
#  'populations': 2,
#  'type': 2,
#  'bnt162': 2,
#  'stem': 2,
#  'transplantation': 2,
#  'bayesian': 2,
#  'lymphocytic': 2,
#  'leukemia': 2,
#  'mrna': 2,
#  'helicobacter': 2,
#  'hypoxia': 2,
#  'survival': 2,
#  'trends': 2,
#  'depressive': 2,
#  'disorder': 2,
#  'major': 2,
#  'internet': 2,
#  'mammography': 2,
#  'bibliometrics': 2,
#  'pregnancy': 2,
#  'nucleotide': 2,
#  'sequencing': 2,
#  'neoplasia': 2,
#  'cross-sectional': 2,
#  'probability': 2,
#  'skin': 2,
#  'masks': 2,
#  'surveys': 2,
#  'weight': 2,
#  'obesity': 2,
#  'transformation': 2,
#  'drug-related': 2,
#  'side': 2,
#  'reactions': 2,
#  'natural': 2,
#  'language': 2,
#  'software': 2,
#  'expression': 2,
#  'clinical': 2,
#  'adrenocortical': 2,
#  'ferroptosis': 2,
#  'hospitalization': 2,
#  'palliative': 2,
#  'life': 2,
#  'information': 2,
#  'system': 2,
#  'records': 2,
#  'male': 2,
#  'factor': 2,
#  'receptor': 2,
#  'prostate-specific': 2,
#  'antigen': 2,
#  'triglycerides': 2,
#  'bone-targeting': 2,
#  'skeletal-related': 2,
#  'guideline': 2,
#  'arsenic': 2,
#  'wells': 2,
#  'hepatitis': 2,
#  'c': 2,
#  'antibody': 1,
#  'baseline': 1,
#  'characteristics': 1,
#  'cd4+': 1,
#  't': 1,
#  'superlearner': 1,
#  'response': 1,
#  'variable': 1,
#  'importance': 1,
#  'measurements': 1,
#  'everolimus': 1,
#  'heterografts': 1,
#  'histone': 1,
#  'deacetylases': 1,
#  'triple': 1,
#  'negative': 1,
#  'contrast': 1,
#  'dtpa': 1,
#  'nomograms': 1,
#  'alpha-fetoproteins': 1,
#  'nomogram': 1,
#  'sciences': 1,
#  'alzheimer': 1,
#  'feasibility': 1,
#  "alzheimer's": 1,
#  'sers': 1,
#  'biosensing': 1,
#  'materials': 1,
#  'science': 1,
#  'nanomaterials': 1,
#  'chemistry': 1,
#  'techniques': 1,
#  'graph': 1,
#  'discovery': 1,
#  'reaction': 1,
#  'template': 1,
#  'recurrent': 1,
#  'retrosynthesis': 1,
#  'meningeal': 1,
#  'meningioma': 1,
#  'neoplasm': 1,
#  'grading': 1,
#  'environment': 1,
#  'italy': 1,
#  'pollution': 1,
#  'mouth': 1,
#  'tumors': 1,
#  'random': 1,
#  'forests': 1,
#  'longitudinal': 1,
#  'adductomics': 1,
#  'cys34': 1,
#  'adductome': 1,
#  'diesel': 1,
#  'engine': 1,
#  'exhaust': 1,
#  'environmental': 1,
#  'mediterranean': 1,
#  'diet': 1,
#  'dietary': 1,
#  'fibers': 1,
#  'gut': 1,
#  'barrier': 1,
#  'mediation': 1,
#  'analyses': 1,
#  'short-chain': 1,
#  'fatty': 1,
#  'surveillance': 1,
#  'interval': 1,
#  'carotid': 1,
#  'coronary': 1,
#  'renal': 1,
#  'vascular': 1,
#  'damage': 1,
#  'radiofrequency': 1,
#  'ablation': 1,
#  'hub': 1,
#  'genes': 1,
#  'cdc': 1,
#  'centers': 1,
#  '2019': 1,
#  'icu': 1,
#  'intensive': 1,
#  'unit': 1,
#  'protective': 1,
#  'severe': 1,
#  'acute': 1,
#  'syndrome': 1,
#  'variant': 1,
#  'convolutional': 1,
#  '(cnn)': 1,
#  'endometrial': 1,
#  'histopathology': 1,
#  'dce-mri': 1,
#  'pam50': 1,
#  'subtypes': 1,
#  'radiogenomics': 1,
#  'japan': 1,
#  'colonic': 1,
#  'localisation': 1,
#  'leak': 1,
#  'correlation': 1,
#  'gastrectomy': 1,
#  'postoperative': 1,
#  'leakage': 1,
#  'immunonutritional': 1,
#  'variability': 1,
#  'trothing': 1,
#  'angiography': 1,
#  'embolism': 1,
#  'dna': 1,
#  'copy': 1,
#  'number': 1,
#  'variations': 1,
#  'diaphragm': 1,
#  'hernias': 1,
#  'mice': 1,
#  'crebbp': 1,
#  'decipher': 1,
#  'smarca4': 1,
#  'uba2': 1,
#  'usp9x': 1,
#  'hernia': 1,
#  'dnmt1': 1,
#  'runx3': 1,
#  'signaling': 1,
#  'pathway': 1,
#  'smbionet': 1,
#  'c-myc': 1,
#  'qualitative': 1,
#  "parkinson's": 1,
#  'bias': 1,
#  'cardiovascular': 1,
#  'stroke': 1,
#  'stratification': 1,
#  'alkanesulfonic': 1,
#  'eagles': 1,
#  'cervix': 1,
#  'uteri': 1,
#  'infectious': 1,
#  'lumbar': 1,
#  'embedding': 1,
#  'protein-protein': 1,
#  'interaction': 1,
#  'axilla': 1,
#  'nodes': 1,
#  'lymphadenopathy': 1,
#  'ultrasound': 1,
#  'inflammation': 1,
#  'illness': 1,
#  'genome-scale': 1,
#  'metabolic': 1,
#  'filariasis': 1,
#  'tropical': 1,
#  'alphapapillomavirus': 1,
#  'acceptance': 1,
#  'bert': 1,
#  'text': 1,
#  'summarization': 1,
#  'prenatal': 1,
#  'monoclonal': 1,
#  'allogeneic': 1,
#  'autologous': 1,
#  'car-t': 1,
#  'hematological': 1,
#  'malignancies': 1,
#  'immunocompromised': 1,
#  'patients': 1,
#  'moderna': 1,
#  'mrna-1273': 1,
#  'non-hodgkin': 1,
#  'lymphoma': 1,
#  'pfizer-biontech': 1,
#  'bnt162b2': 1,
#  'probabilistic': 1,
#  'graphical': 1,
#  'differential': 1,
#  'hashimoto': 1,
#  'hypothyroidism': 1,
#  'ultrasonography': 1,
#  'pylori': 1,
#  'logistic': 1,
#  'metabolism': 1,
#  'immune': 1,
#  'landscape': 1,
#  'overall': 1,
#  'implications': 1,
#  'arima': 1,
#  'google': 1,
#  'nnar': 1,
#  'romania': 1,
#  'tbats': 1,
#  'incidence': 1,
#  'antidepressive': 1,
#  'cognitive': 1,
#  'behavioral': 1,
#  'primary': 1,
#  'outcome': 1,
#  'antidepressant': 1,
#  'medication': 1,
#  'appalachian': 1,
#  'mind': 1,
#  'initiative': 1,
#  '(amhi)': 1,
#  'remission': 1,
#  'from': 1,
#  'i-cbt': 1,
#  'cardio-oncology': 1,
#  'cardiomyopathy': 1,
#  'electrocardiography': 1,
#  'malignancy': 1,
#  'pharmacology': 1,
#  'combined': 1,
#  'chemotherapy': 1,
#  'protocols': 1,
#  'combinations': 1,
#  'cd8-positive': 1,
#  't-lymphocytes': 1,
#  'immunoglobulin': 1,
#  'g': 1,
#  'proteomics': 1,
#  'calcinosis': 1,
#  'delivery': 1,
#  'publications': 1,
#  'scopus': 1,
#  'cicatrix': 1,
#  'hypertrophic': 1,
#  'keloid': 1,
#  'child': 1,
#  'cohort': 1,
#  'infant': 1,
#  'newborn': 1,
#  'premature': 1,
#  'hba1c': 1,
#  'preconception': 1,
#  'preterm': 1,
#  'high-throughput': 1,
#  'vaginal': 1,
#  'smears': 1,
#  'intraepithelial': 1,
#  'high': 1,
#  'human': 1,
#  'papilloma': 1,
#  'targeted': 1,
#  'omics': 1,
#  'adult': 1,
#  'colombia': 1,
#  'hard-to-reach': 1,
#  'women': 1,
#  'belief': 1,
#  'no-show': 1,
#  'speech': 1,
#  'students': 1,
#  'q': 1,
#  'fractional': 1,
#  'calculus': 1,
#  'things': 1,
#  'routing': 1,
#  'questionnaires': 1,
#  'face': 1,
#  'hierarchical': 1,
#  'mobile': 1,
#  'applications': 1,
#  'personal': 1,
#  'satisfaction': 1,
#  'telemedicine': 1,
#  'loss': 1,
#  'saliva': 1,
#  'colon': 1,
#  'differentially': 1,
#  'methylated': 1,
#  'regions': 1,
#  'generalized': 1,
#  'regression': 1,
#  'biomarker': 1,
#  'expert': 1,
#  'panel': 1,
#  'pathologist': 1,
#  'training': 1,
#  'education': 1,
#  'tumor-infiltrating': 1,
#  'lymphocytes': 1,
#  'validation': 1,
#  'dataset': 1,
#  'richter': 1,
#  '(rt)': 1,
#  'accelerated': 1,
#  'cll': 1,
#  'cellular': 1,
#  'engineering': 1,
#  '(cll)': 1,
#  'progression': 1,
#  'fusion': 1,
#  'selection': 1,
#  'large': 1,
#  'unsupervised': 1,
#  'clustering': 1,
#  'telemedecine': 1,
#  'microscopy': 1,
#  'phenomics': 1,
#  'phenotype': 1,
#  'time-lapse': 1,
#  'decision-making': 1,
#  'recommendation': 1,
#  'extraction': 1,
#  'segmentation': 1,
#  'seer': 1,
#  'node': 1,
#  'multicenter': 1,
#  'osteosarcoma': 1,
#  'web': 1,
#  'calculator': 1,
#  'adrenal': 1,
#  'cortex': 1,
#  'regulation': 1,
#  'neoplastic': 1,
#  'lasso': 1,
#  'trials': 1,
#  'service': 1,
#  'research': 1,
#  'statistics': 1,
#  'services': 1,
#  'demand': 1,
#  'end': 1,
#  '(mis)': 1,
#  'micrornas': 1,
#  'politics': 1,
#  'hospitals': 1,
#  'non-small-cell': 1,
#  'erbb': 1,
#  'receptors': 1,
#  'mutation': 1,
#  'epidermal': 1,
#  'growth': 1,
#  'non-small': 1,
#  'hiv': 1,
#  'anal': 1,
#  'squamous-cell': 1,
#  'middle': 1,
#  'aged': 1,
#  'prostatic': 1,
#  'national': 1,
#  'examination': 1,
#  'survey': 1,
#  '(nhanes)': 1,
#  'prostate': 1,
#  'body': 1,
#  'rehabilitation': 1,
#  'melanoma': 1,
#  'quality': 1,
#  'accuracy': 1,
#  'ensemble': 1,
#  'forecast': 1,
#  'evaluation': 1,
#  'proteins': 1,
#  'matrix-assisted': 1,
#  'laser': 1,
#  'desorption-ionization': 1,
#  'tissue': 1,
#  'diagnostics': 1,
#  'auroc': 1,
#  'bta': 1,
#  'agent': 1,
#  'cpt': 1,
#  'current': 1,
#  'procedural': 1,
#  'terminology': 1,
#  'denosumab': 1,
#  'ecog': 1,
#  'eastern': 1,
#  'cooperative': 1,
#  'group': 1,
#  'ehr': 1,
#  'record': 1,
#  'esmo': 1,
#  'european': 1,
#  'society': 1,
#  'hcpcs': 1,
#  'healthcare': 1,
#  'common': 1,
#  'procedure': 1,
#  'coding': 1,
#  'icd': 1,
#  'international': 1,
#  'onj': 1,
#  'osteonecrosis': 1,
#  'jaw': 1,
#  'phi': 1,
#  'protected': 1,
#  'q4w': 1,
#  'every': 1,
#  'four': 1,
#  'weeks': 1,
#  'rankl': 1,
#  'activator': 1,
#  'nuclear': 1,
#  'kappabeta': 1,
#  'ligand': 1,
#  'roc': 1,
#  'observational': 1,
#  'study': 1,
#  'shap': 1,
#  'shapley': 1,
#  'additive': 1,
#  'explanations': 1,
#  'sre': 1,
#  'event': 1,
#  'events': 1,
#  'xgb': 1,
#  'extreme': 1,
#  'gradient': 1,
#  'boost': 1,
#  'eshre': 1,
#  'adolescent': 1,
#  'endometriosis': 1,
#  'fertility': 1,
#  'pain': 1,
#  'intervention': 1,
#  'pediatric': 1,
#  'single': 1,
#  'polymorphisms': 1,
#  'drinking': 1,
#  'groundwater': 1,
#  'pollutants': 1,
#  'supply': 1,
#  'outcomes': 1,
#  'private': 1,
#  'contamination': 1,
#  'aging': 1,
#  'age': 1,
#  'clocks': 1,
#  'microbiome': 1,
#  'creation': 1,
#  'pinpoint': 1,
#  'twitter': 1,
#  'general': 1,
#  'providers': 1,
#  'pancreatic': 1,
#  'social': 1,
#  'thematic': 1,
#  'photochemotherapy': 1,
#  'spectrum': 1,
#  'alpha': 1,
#  'fetoprotein': 1,
#  '(afp)': 1,
#  '(hcc)': 1,
#  '(svm)': 1,
#  'surface-enhanced': 1,
#  '(sers)': 1,
#  'urine': 1,
#  'aspartate': 1,
#  'aminotransferases': 1,
#  'hepacivirus': 1,
#  'hepatology': 1,
#  'reinforcement': 1,
#  'risk-based': 1,
#  'chromosome': 1,
#  'aberrations': 1,
#  'genomics': 1,
#  'myelodysplastic': 1,
#  'syndromes': 1,
#  'mutations': 1,
#  'myeloid': 1,
#  'prognostic': 1,
#  'scoring': 1,
#  'linear': 1,
#  'prospective': 1}

# %%
# ok but were do i check for matches? title? keywords? abstract?
list(dic.keys())[0:5]
# Out:
# ['learning', 'machine', 'humans', 'diagnosis', 'neoplasms']
