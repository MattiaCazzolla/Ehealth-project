# %% [markdown]
# # Relevance Score
# For each paper we have to compute a relevance score which should state how relevant that paper is compared to the search we made. <br>
#
# So i was thinking something like this:<br>
# paper1 ---> score : 1 (exactly what we were looking for)<br>
# paper2 ---> score : 0 (treats a completly different topic)<br>
# and the rest of the cases are between 0 and 1
#
# Strategies:
# - [Title Matches](#section_id)
# - [Keywords matches](#section_id2)
# - [Title and Keywords matches](#section_id3)
# - [Automatic dictionary from abstracts](#section_id4)
# - [Automatic dictionary from keywords](#section_id5)

# %%
import requests
import json
import time
import pandas as pd

# %%
def esearch(search_term):
    search_term = search_term.strip().replace(' ', '+')
    url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi'
    url = url + '?db=pubmed' + '&retmode=json' + '&retmax=500'
    url = url + '&term=' + search_term
    site = requests.get(url).content
    json_site = json.loads(site.decode()) 
    UIDs = json_site['esearchresult']['idlist']
    return UIDs

# %%
def efetch(UIDs):
    session = requests.Session()
    abstracts = []
    keywords = []
    titles = []
    i = 1
    for UID in UIDs:
        time.sleep(0.4)
        url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi'
        url = url + '?db=pubmed' + '&rettype=medline&id='
        url = url + UID
        
        data = session.get(url).content
        data = data.decode()
        data = data.split('\n')
        
        
        ls = []
        for elem in data:
            if elem == '':
                continue
            elif elem[0:4] != '    ': 
                elem = elem.strip()
                elem = elem.replace('\n', '')
                ls.append(elem)
            else:                    
                elem = elem.strip()
                elem = elem.replace('\n', '')
                ls[-1] = ls[-1] + elem
    
    
        ls_2 = [] 
        for elem in ls:
            key = elem[0:4].strip()
            value = elem[5:].strip()
            ls_2.append([key, value])
        
        all_key = ''
        abst = ''
        for row in ls_2:
            if row[0] == 'AB':
                abst = abst + row[1]
            
            elif row[0] == 'OT' or row[0] == 'MH':
                all_key = all_key + row[1] + ', '
            
            elif row[0] == 'TI':
                titles.append(row[1])
                
        keywords.append(all_key[:-2])
        abstracts.append(abst)
        
        if i%10==0:
            print('Paper ' + str(i) +': OK')
        i += 1
        
    dic = {
        'UID' : UIDs,
        'title' : titles,
        'abstarct' : abstracts,
        'keywords' : keywords
    }
    return dic

# %%
UIDs = esearch('machine learning cancer prevention')
data = efetch(UIDs)
# Out:
# Paper 10: OK
# Paper 20: OK
# Paper 30: OK
# Paper 40: OK
# Paper 50: OK
# Paper 60: OK
# Paper 70: OK
# Paper 80: OK
# Paper 90: OK
# Paper 100: OK
# Paper 110: OK
# Paper 120: OK
# Paper 130: OK
# Paper 140: OK
# Paper 150: OK
# Paper 160: OK
# Paper 170: OK
# Paper 180: OK
# Paper 190: OK
# Paper 200: OK
# Paper 210: OK
# Paper 220: OK
# Paper 230: OK
# Paper 240: OK
# Paper 250: OK
# Paper 260: OK
# Paper 270: OK
# Paper 280: OK
# Paper 290: OK
# Paper 300: OK
# Paper 310: OK
# Paper 320: OK
# Paper 330: OK
# Paper 340: OK
# Paper 350: OK
# Paper 360: OK
# Paper 370: OK
# Paper 380: OK
# Paper 390: OK
# Paper 400: OK
# Paper 410: OK
# Paper 420: OK
# Paper 430: OK
# Paper 440: OK
# Paper 450: OK
# Paper 460: OK
# Paper 470: OK
# Paper 480: OK
# Paper 490: OK
# Paper 500: OK

# %%
df = pd.DataFrame(data)
df
# Out:
#           UID                                              title  \
# 0    36179551  Baseline host determinants of robust human HIV...
# 1    36168036  Molecular pathways enhance drug response predi...
# 2    36159773  Comparative Analysis of Machine Learning Metho...
# 3    36159011  Radiomics and nomogram of magnetic resonance i...
# 4    36157578  The integrated landscape of eRNA in gastric ca...
# ..        ...                                                ...
# 495  25540094  Multilevel modeling and value of information i...
# 496  25423479  Identifying predictive features in drug respon...
# 497  25189363  Computer-aided detection of exophytic renal le...
# 498  24732597  Gene expression profile alone is inadequate in...
# 499  23781004  L1CAM in early-stage type I endometrial cancer...
#
#                                               abstarct  \
# 0    BACKGROUND: The identification of baseline hos...
# 1    Computational models have been successful in p...
# 2    Breast cancer is the leading cancer in women, ...
# 3    BACKGROUND: Microvascular invasion (MVI) of sm...
# 4    The comprehensive regulation effect of eRNA on...
# ..                                                 ...
# 495  BACKGROUND: Clinical trials are the main metho...
# 496  This article reviews several techniques from m...
# 497  Renal lesions are important extracolonic findi...
# 498  With advent of several treatment options in mu...
# 499  BACKGROUND: Despite the excellent prognosis of...
#
#                                               keywords
# 0    Antibody, Baseline characteristics, CD4+ T cel...
# 1    Cell Line, Cell Line, Tumor, *Everolimus, Hete...
# 2    *Breast Neoplasms/diagnosis/genetics, Female, ...
# 3    *Carcinoma, Hepatocellular/diagnostic imaging/...
# 4    Bioinformatics, Biological sciences, Cancer, S...
# ..                                                 ...
# 495  Arabidopsis, Decision Support Techniques, Esch...
# 496  Algorithms, Animals, Antineoplastic Agents/adv...
# 497  Adult, Aged, Algorithms, Artificial Intelligen...
# 498  Genetic Testing, Humans, Microarray Analysis, ...
# 499  Adult, Aged, Biomarkers, Tumor/*analysis, Brac...
#
# [500 rows x 4 columns]

# %% [markdown]
# <a id='section_id'></a>

# %% [markdown]
# # Title matches
# one strategy might be to see if there is a match between the search term and the title <br>
# we can compute the score like: (matching terms in the title)/(total search terms)

# %%
def process_text(text):
    text = text.strip()
    text = text.lower()
    text = text.replace('.', ' ')
    text = text.replace(',', ' ')
    text = text.replace(':', ' ')
    text = text.replace(';', ' ')
    text = text.replace('*', ' ')
    text = text.replace('/', ' ')
    text = text.replace('-', ' ')
    text = text.replace('&', ' ')
    text = text.replace('=', ' ')
    return text

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
titles = df['title'].tolist()
for title in titles:
    title = process_text(title)
    matchs = 0
    for word in search_term:
        if word in title:
            matchs += 1
    scores.append(matchs/len(search_term))

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2
# Out:
#                                                  title  score
# 338  Cancer Prevention Using Machine Learning, Nudg...   1.00
# 331  Machine learning highlights the deficiency of ...   1.00
# 54   Artificial Intelligence and Machine Learning i...   0.75
# 65   Development of Training Materials for Patholog...   0.75
# 316  Machine learning can accelerate discovery and ...   0.75
# ..                                                 ...    ...
# 238  Mitochondriopathies as a Clue to Systemic Diso...   0.00
# 243  Pathogenesis, Symptomatology, and Transmission...   0.00
# 244  Modeling of diagnosis for metabolic syndrome b...   0.00
# 246  Autism Spectrum Disorder from the Womb to Adul...   0.00
# 250  GAERF: predicting lncRNA-disease associations ...   0.00
#
# [500 rows x 2 columns]

# %%
 for elem in df2[df2['score']==1]['title'].values:
        print(elem)
        print()
# Out:
# Cancer Prevention Using Machine Learning, Nudge Theory and Social Impact Bond.
#
# Machine learning highlights the deficiency of conventional dosimetric constraintsfor prevention of high-grade radiation esophagitis in non-small cell lung cancertreated with chemoradiation.

# %%
df2.head()
# Out:
#                                                  title  score
# 338  Cancer Prevention Using Machine Learning, Nudg...   1.00
# 331  Machine learning highlights the deficiency of ...   1.00
# 54   Artificial Intelligence and Machine Learning i...   0.75
# 65   Development of Training Materials for Patholog...   0.75
# 316  Machine learning can accelerate discovery and ...   0.75

# %% [markdown]
# <a id='section_id2'></a>

# %% [markdown]
# # Keywords matches
# same as title but for keywords

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
keywords = df['keywords'].tolist()
for keys in keywords:
    keys = process_text(keys)
    matchs = 0
    for word in search_term:
        if word in keys:
            matchs += 1
    scores.append(matchs/len(search_term))

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2
# Out:
#                                                  title  score
# 248  Assessing Lung Cancer Absolute Risk Trajectory...    1.0
# 164  Identifying False Human Papillomavirus (HPV) V...    1.0
# 418  Prospective validation of the NCI Breast Cance...    1.0
# 177  Changes in Immune Cell Types with Age in Breas...    1.0
# 443  Predictors of the Healthy Eating Index and Gly...    1.0
# ..                                                 ...    ...
# 382  Etiological Role of Diet in 30-Day Readmission...    0.0
# 254  A roadmap of six different pathways to improve...    0.0
# 243  Pathogenesis, Symptomatology, and Transmission...    0.0
# 241  Identifying Stage II Colorectal Cancer Recurre...    0.0
# 0    Baseline host determinants of robust human HIV...    0.0
#
# [500 rows x 2 columns]

# %%
for elem in df2[df2['score']==1.0]['title'].values:
        print(elem)
        print()
# Out:
# Assessing Lung Cancer Absolute Risk Trajectory Based on a Polygenic Risk Model.
#
# Identifying False Human Papillomavirus (HPV) Vaccine Information andCorresponding Risk Perceptions From Twitter: Advanced Predictive Models.
#
# Prospective validation of the NCI Breast Cancer Risk Assessment Tool (Gail Model)on 40,000 Australian women.
#
# Changes in Immune Cell Types with Age in Breast are Consistent with a Decline inImmune Surveillance and Increased Immunosuppression.
#
# Predictors of the Healthy Eating Index and Glycemic Index in Multi-EthnicColorectal Cancer Families.
#
# Bidirectional deep neural networks to integrate RNA and DNA data for predictingoutcome for patients with hepatocellular carcinoma.
#
# A data-driven ultrasound approach discriminates pathological high grade prostatecancer.
#
# An immunogenic personal neoantigen vaccine for patients with melanoma.
#
# Quantitative ultrasound image analysis of axillary lymph nodes to differentiatemalignancy from reactive benign changes due to COVID-19 vaccination.
#
# Increasing Women's Knowledge about HPV Using BERT Text Summarization: An OnlineRandomized Study.
#
# Predicting Peritoneal Metastasis of Gastric Cancer Patients Based on MachineLearning.
#
# Association between Serum Triglycerides and Prostate Specific Antigen (PSA) amongU.S. Males: National Health and Nutrition Examination Survey (NHANES), 2003-2010.
#
# Risk Stratification Strategies for Colorectal Cancer Screening: From LogisticRegression to Artificial Intelligence.
#
# Recent developments and advances in secondary prevention of lung cancer.
#
# Spatial distribution of esophageal cancer mortality in China: a machine learningapproach.
#
# Deep Learning Localizes and Identifies Polyps in Real Time With 96% Accuracy inScreening Colonoscopy.
#
# Thirty years of translational research in Mobility Medicine: Collection ofabstracts of the 2020 Padua Muscle Days.
#
# Artificial intelligence for the prevention and clinical management ofhepatocellular carcinoma.
#
# Artificial Intelligence and Machine Learning in Cancer Research: A Systematic andThematic Analysis of the Top 100 Cited Articles Indexed in Scopus Database.
#
# Carotenoids in Cancer Metastasis-Status Quo and Outlook.
#
# A 10-Year Probability Deep Neural Network Prediction Model for Lung Cancer.
#
# A novel gene panel for prediction of lymph-node metastasis and recurrence inpatients with thyroid cancer.
#
# Make Intelligent of Gastric Cancer Diagnosis Error in Qazvin's Medical Centers:Using Data Mining Method.
#
# Estimating heterogeneous survival treatment effects of lung cancer screeningapproaches: A causal machine learning analysis.
#
# Genomic features of rapid versus late relapse in triple negative breast cancer.
#
# Infectious disease mRNA vaccines and a review on epitope prediction for vaccinedesign.
#
# Identifying predictive features in drug response using machine learning:opportunities and challenges.
#
# Extracellular Domains I and II of cell-surface glycoprotein CD44 mediate itstrans-homophilic dimerization and tumor cluster aggregation.
#
# Predicting sun protection measures against skin diseases using machine learningapproaches.
#
# Targeting the genetic landscape of oral potentially malignant disorders has thepotential as a preventative strategy in oral cancer.
#
# Cancer Prevention Using Machine Learning, Nudge Theory and Social Impact Bond.
#
# PCM-SABRE: a platform for benchmarking and comparing outcome prediction methodsin precision cancer medicine.

# %% [markdown]
# <a id='section_id3'></a>

# %% [markdown]
# # Title and Keywords matches

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
keywords = df['keywords'].tolist()
titles = df['title'].tolist()
for i in range(len(titles)):
    titles[i] = process_text(titles[i])
    keywords[i] = process_text(keywords[i])
    matchs = 0
    for word in search_term:
        if word in keywords[i]:
            matchs += 1
        if word in titles[i]:
            matchs += 1
    scores.append(matchs)

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2['score'] = df2['score'].apply(lambda x: x/max(df2['score']))
df2
# Out:
#                                                  title  score
# 338  cancer prevention using machine learning  nudg...  1.000
# 315  spatial distribution of esophageal cancer mort...  0.875
# 268  predicting peritoneal metastasis of gastric ca...  0.875
# 54   artificial intelligence and machine learning i...  0.875
# 331  machine learning highlights the deficiency of ...  0.875
# ..                                                 ...    ...
# 93   utilization of host and microbiome features in...  0.000
# 428  hlbs popomics  an online knowledge base to acc...  0.000
# 102  application of p4 (predictive  preventive  per...  0.000
# 111  an improved molecular inversion probe based ta...  0.000
# 0    baseline host determinants of robust human hiv...  0.000
#
# [500 rows x 2 columns]

# %%
for elem in df2.head(10)['title'].values:
        print(elem)
        print()
# Out:
# cancer prevention using machine learning  nudge theory and social impact bond
#
# spatial distribution of esophageal cancer mortality in china  a machine learningapproach
#
# predicting peritoneal metastasis of gastric cancer patients based on machinelearning
#
# artificial intelligence and machine learning in cancer research  a systematic andthematic analysis of the top 100 cited articles indexed in scopus database
#
# machine learning highlights the deficiency of conventional dosimetric constraintsfor prevention of high grade radiation esophagitis in non small cell lung cancertreated with chemoradiation
#
# estimating heterogeneous survival treatment effects of lung cancer screeningapproaches  a causal machine learning analysis
#
# classification tree based machine learning to visualize and validate a decisiontool for identifying malnutrition in cancer patients
#
# machine learning assisted discrimination of precancerous and cancerous fromhealthy oral tissue based on multispectral autofluorescence lifetime imagingendoscopy
#
# machine learning techniques for personalized breast cancer risk prediction comparison with the bcrat and boadicea models
#
# prediction of her2 expression in breast cancer by combining pet ct radiomicanalysis and machine learning

# %% [markdown]
# <a id='section_id4'></a>

# %% [markdown]
# # Automatic dictionary from abstracts
# idea of the tutor i overheard <br>
# basically build a dictionary of the most common words in the abstracts and then use this list to check for matches (in title? in abstract? i have no idea)

# %%
def process_text(text):
    text = text.strip()
    text = text.lower()
    text = text.replace('.', ' ')
    text = text.replace(',', ' ')
    text = text.replace(':', ' ')
    text = text.replace(';', ' ')
    text = text.replace('*', ' ')
    text = text.replace('/', ' ')
    text = text.replace('-', ' ')
    text = text.replace('&', ' ')
    text = text.replace('=', ' ')
    return text

# %%
def word_freq(text, dic):
    text = process_text(text)
    text = text.split()
    for word in text:
        if word not in dic:
            dic[word] = 0
        dic[word] += 1
    return dic

# %%
abstracts = df['abstarct'].tolist()

# %%
dic = {key: val for key, val in sorted(dic.items(), key = lambda ele: ele[1], reverse = True)}

# %%
# most common words are not the one we care about
dic
# Out:
# {'the': 5756,
#  'and': 4506,
#  'of': 4464,
#  'to': 2554,
#  'in': 2366,
#  'a': 1886,
#  'for': 1491,
#  'with': 1251,
#  '0': 933,
#  'cancer': 914,
#  'is': 845,
#  'we': 751,
#  'on': 698,
#  'that': 672,
#  'were': 671,
#  'was': 659,
#  'this': 642,
#  'as': 616,
#  'from': 586,
#  'by': 569,
#  'learning': 564,
#  'model': 555,
#  'patients': 534,
#  'data': 496,
#  'risk': 474,
#  'are': 452,
#  'machine': 447,
#  'based': 442,
#  'an': 432,
#  'using': 396,
#  'results': 384,
#  'be': 374,
#  'study': 364,
#  'clinical': 350,
#  'models': 346,
#  'methods': 344,
#  '1': 343,
#  'can': 306,
#  'used': 303,
#  'at': 289,
#  'or': 282,
#  '2': 253,
#  'analysis': 248,
#  'have': 242,
#  'which': 237,
#  'disease': 231,
#  'prediction': 229,
#  'these': 226,
#  'our': 224,
#  'accuracy': 217,
#  'treatment': 217,
#  'high': 215,
#  'features': 215,
#  'has': 214,
#  'breast': 208,
#  'prevention': 202,
#  'performance': 199,
#  'health': 190,
#  'tumor': 183,
#  'between': 177,
#  'method': 176,
#  'diagnosis': 175,
#  'been': 171,
#  'detection': 166,
#  'most': 162,
#  'also': 155,
#  'it': 154,
#  'such': 151,
#  '3': 149,
#  'more': 148,
#  'research': 146,
#  'associated': 146,
#  'deep': 146,
#  'all': 145,
#  'may': 144,
#  'patient': 144,
#  'identify': 144,
#  'images': 144,
#  'potential': 142,
#  'factors': 142,
#  'validation': 140,
#  'than': 139,
#  'screening': 138,
#  'not': 136,
#  'into': 136,
#  '19': 136,
#  'set': 135,
#  'two': 134,
#  'compared': 134,
#  'predictive': 134,
#  'time': 134,
#  'related': 132,
#  'ai': 132,
#  'background': 131,
#  'lung': 131,
#  'network': 129,
#  'developed': 129,
#  'algorithms': 129,
#  'however': 128,
#  'classification': 127,
#  'their': 126,
#  'use': 126,
#  'information': 125,
#  'had': 125,
#  'algorithm': 125,
#  'system': 125,
#  'predict': 125,
#  'covid': 125,
#  'cell': 123,
#  'including': 123,
#  'sensitivity': 123,
#  'early': 123,
#  'survival': 122,
#  'both': 121,
#  'ci': 120,
#  'other': 120,
#  'test': 120,
#  'conclusions': 118,
#  'identified': 117,
#  'one': 117,
#  'age': 117,
#  'p': 117,
#  'studies': 114,
#  'imaging': 114,
#  'important': 113,
#  'genes': 113,
#  'low': 111,
#  'approach': 109,
#  'could': 107,
#  'well': 107,
#  'after': 106,
#  'showed': 105,
#  'new': 104,
#  'diseases': 103,
#  'support': 103,
#  '5': 102,
#  'specific': 100,
#  'development': 100,
#  'respectively': 99,
#  'specificity': 99,
#  'mortality': 99,
#  'regression': 98,
#  'cohort': 98,
#  'training': 98,
#  'value': 97,
#  'cases': 97,
#  'among': 96,
#  'care': 96,
#  'but': 96,
#  'women': 95,
#  'score': 95,
#  'proposed': 95,
#  'different': 94,
#  'each': 93,
#  'will': 92,
#  'primary': 92,
#  'under': 91,
#  'gene': 91,
#  'conclusion': 90,
#  'evaluated': 90,
#  'outcomes': 89,
#  'curve': 89,
#  'random': 89,
#  '<': 89,
#  'its': 89,
#  'develop': 88,
#  'neural': 88,
#  'improve': 87,
#  'testing': 87,
#  'medical': 87,
#  'predicting': 86,
#  'three': 85,
#  'higher': 85,
#  'cells': 85,
#  'expression': 84,
#  'years': 84,
#  'human': 83,
#  'image': 83,
#  'only': 83,
#  '95%': 83,
#  'total': 82,
#  'provide': 82,
#  'tool': 82,
#  '4': 82,
#  '(n': 82,
#  'biomarkers': 82,
#  'ml': 82,
#  'non': 81,
#  'forest': 81,
#  'prognostic': 81,
#  'ct': 81,
#  'immune': 80,
#  'samples': 80,
#  'there': 80,
#  'significantly': 80,
#  'when': 79,
#  'area': 79,
#  'medicine': 78,
#  'while': 78,
#  'auc': 77,
#  'diagnostic': 77,
#  '6': 77,
#  'type': 77,
#  'dose': 76,
#  '(0': 76,
#  'further': 76,
#  'precision': 76,
#  'feature': 76,
#  'decision': 76,
#  'effective': 76,
#  'techniques': 76,
#  'cervical': 76,
#  'role': 75,
#  'datasets': 75,
#  'rate': 75,
#  'group': 75,
#  'cov': 75,
#  'level': 74,
#  'significant': 74,
#  'drug': 74,
#  'selection': 74,
#  'number': 74,
#  '(p': 73,
#  'up': 73,
#  'liver': 71,
#  'over': 70,
#  'included': 70,
#  'artificial': 70,
#  'intelligence': 70,
#  'review': 70,
#  '10': 69,
#  'approaches': 68,
#  'novel': 68,
#  'stage': 68,
#  'due': 67,
#  'tissue': 67,
#  'large': 67,
#  'status': 66,
#  'should': 66,
#  'best': 66,
#  'through': 66,
#  'performed': 66,
#  'findings': 65,
#  'overall': 65,
#  'cancers': 65,
#  'hospital': 65,
#  'dataset': 65,
#  'year': 65,
#  'participants': 64,
#  'who': 64,
#  'therapy': 64,
#  'those': 64,
#  '+': 64,
#  'applied': 64,
#  'future': 63,
#  'selected': 63,
#  'current': 63,
#  'within': 62,
#  't': 62,
#  'how': 62,
#  'several': 62,
#  'positive': 61,
#  'variables': 61,
#  'prognosis': 61,
#  'population': 61,
#  'activity': 61,
#  'achieved': 60,
#  'genetic': 60,
#  'then': 60,
#  '001)': 60,
#  'sars': 60,
#  'vs': 60,
#  'objective': 60,
#  'single': 60,
#  'response': 59,
#  'molecular': 59,
#  'found': 59,
#  '7': 58,
#  'first': 58,
#  'evaluate': 58,
#  '8': 58,
#  'management': 58,
#  'systems': 58,
#  '(95%': 57,
#  'across': 57,
#  'blood': 57,
#  'factor': 57,
#  'strategies': 57,
#  'available': 57,
#  'multi': 57,
#  'types': 57,
#  'mean': 57,
#  'application': 57,
#  'cross': 56,
#  'accurate': 56,
#  'pathology': 56,
#  'need': 56,
#  'individual': 55,
#  'obtained': 55,
#  'assessment': 55,
#  'validated': 54,
#  'predictors': 54,
#  'analyses': 54,
#  'negative': 54,
#  'analyzed': 54,
#  'index': 54,
#  'vector': 54,
#  'four': 53,
#  'average': 53,
#  'rates': 53,
#  'improved': 53,
#  'infection': 53,
#  'able': 53,
#  'various': 53,
#  'identification': 52,
#  'aim': 52,
#  'increased': 52,
#  'purpose': 52,
#  'present': 52,
#  'control': 52,
#  'characteristics': 51,
#  'here': 51,
#  'during': 51,
#  'trained': 51,
#  'key': 51,
#  'increase': 51,
#  'case': 51,
#  'better': 51,
#  'many': 51,
#  'progression': 50,
#  'levels': 50,
#  'common': 50,
#  'colorectal': 50,
#  'effect': 49,
#  'tools': 49,
#  'recurrence': 49,
#  'quality': 49,
#  'some': 49,
#  'public': 49,
#  'multiple': 49,
#  'evaluation': 49,
#  '12': 48,
#  'help': 48,
#  'collected': 48,
#  'groups': 48,
#  '9': 48,
#  'demonstrated': 48,
#  'hpv': 48,
#  'carcinoma': 47,
#  'combination': 47,
#  'no': 47,
#  'e': 47,
#  'digital': 47,
#  'knowledge': 47,
#  'effects': 47,
#  'vaccine': 46,
#  'importance': 46,
#  'radiomics': 46,
#  'changes': 46,
#  'known': 46,
#  'omics': 46,
#  'metastasis': 46,
#  'challenges': 46,
#  'prostate': 46,
#  'machinelearning': 45,
#  'grade': 45,
#  'lesions': 45,
#  'protein': 45,
#  'out': 45,
#  'upon': 45,
#  'trials': 44,
#  'independent': 44,
#  'quantitative': 44,
#  'outcome': 44,
#  'individuals': 44,
#  'parameters': 44,
#  'mass': 44,
#  'understanding': 44,
#  'incidence': 44,
#  'applications': 44,
#  'computational': 43,
#  'observed': 43,
#  'scores': 43,
#  'classifier': 43,
#  'existing': 43,
#  'long': 43,
#  'provides': 43,
#  'practice': 43,
#  'state': 43,
#  'making': 42,
#  'receiver': 42,
#  'technology': 42,
#  'ability': 42,
#  'five': 42,
#  'technologies': 42,
#  'without': 42,
#  'recent': 42,
#  'work': 41,
#  'tumors': 41,
#  'leading': 41,
#  'logistic': 41,
#  'extracted': 41,
#  'surgery': 41,
#  'oral': 41,
#  'u': 41,
#  'although': 41,
#  'design': 41,
#  'university': 41,
#  'database': 41,
#  'impact': 41,
#  'process': 40,
#  'operating': 40,
#  'cause': 40,
#  'standard': 40,
#  'least': 40,
#  'volume': 40,
#  'mechanisms': 40,
#  'about': 40,
#  'i': 40,
#  'sample': 40,
#  'major': 39,
#  'paper': 39,
#  'determine': 39,
#  'identifying': 39,
#  'characteristic': 39,
#  'monitoring': 39,
#  'nodules': 39,
#  'world': 39,
#  'completion': 39,
#  'tests': 39,
#  'complex': 39,
#  'conducted': 38,
#  'assessed': 38,
#  '50': 38,
#  'lower': 38,
#  'gastric': 38,
#  'critical': 38,
#  'field': 38,
#  'ratio': 38,
#  'evidence': 38,
#  'trial': 38,
#  'cost': 38,
#  'promising': 38,
#  'developing': 38,
#  'lymph': 38,
#  'show': 38,
#  'detect': 38,
#  'hcc': 38,
#  'pancreatic': 38,
#  'aimed': 37,
#  '2%': 37,
#  'scale': 37,
#  'derived': 37,
#  'biological': 37,
#  'addition': 37,
#  'combined': 37,
#  'oncology': 37,
#  'healthcare': 37,
#  'result': 37,
#  'optimal': 37,
#  'predicted': 37,
#  '>': 37,
#  '%': 37,
#  'real': 37,
#  'assay': 36,
#  'versus': 36,
#  'setting': 36,
#  'diagnosed': 36,
#  'months': 36,
#  'finally': 36,
#  'follow': 36,
#  'net': 36,
#  'therefore': 36,
#  'per': 36,
#  'networks': 36,
#  'anti': 36,
#  'louisville': 36,
#  'size': 35,
#  'framework': 35,
#  'death': 35,
#  'term': 35,
#  'therapeutic': 35,
#  'highest': 35,
#  'drugs': 34,
#  'convolutional': 34,
#  'smoking': 34,
#  'presence': 34,
#  'radiation': 34,
#  '2019': 34,
#  'controls': 34,
#  'virus': 34,
#  'pandemic': 34,
#  'reduce': 34,
#  'segmentation': 34,
#  'measures': 34,
#  'associations': 34,
#  'useful': 34,
#  'generated': 34,
#  'svm': 34,
#  'node': 34,
#  'metabolic': 34,
#  'pain': 34,
#  'healthy': 34,
#  'tested': 34,
#  '30': 33,
#  'genomic': 33,
#  'association': 33,
#  'mri': 33,
#  'differences': 33,
#  'whether': 33,
#  'next': 33,
#  'thus': 33,
#  'they': 33,
#  'life': 33,
#  'error': 33,
#  'statistical': 32,
#  'relevant': 32,
#  'given': 32,
#  'diabetes': 32,
#  'via': 32,
#  'social': 32,
#  'efficacy': 32,
#  'describe': 32,
#  'panel': 32,
#  'reduction': 32,
#  'invasive': 32,
#  'especially': 32,
#  '90': 32,
#  'assess': 31,
#  'post': 31,
#  'national': 31,
#  'small': 31,
#  'currently': 31,
#  'previous': 31,
#  'experimental': 31,
#  'followed': 31,
#  '(ai)': 31,
#  'become': 31,
#  'utility': 31,
#  'growth': 31,
#  'computer': 31,
#  'top': 31,
#  'focus': 31,
#  '0%': 31,
#  'acute': 31,
#  'dna': 31,
#  'implementation': 31,
#  'provided': 31,
#  'interventions': 31,
#  'robust': 31,
#  'having': 31,
#  'reported': 31,
#  'patterns': 30,
#  'predictions': 30,
#  'confirmed': 30,
#  'cohorts': 30,
#  'correlation': 30,
#  'target': 30,
#  'symptoms': 30,
#  's': 30,
#  '3%': 30,
#  'vaccines': 30,
#  'additional': 30,
#  'c': 30,
#  'prior': 30,
#  'laboratory': 30,
#  'regions': 30,
#  '3d': 30,
#  'baseline': 29,
#  'propose': 29,
#  'classifiers': 29,
#  'against': 29,
#  'order': 29,
#  'clinically': 29,
#  'being': 29,
#  'burden': 29,
#  'ensemble': 29,
#  'colonoscopy': 29,
#  'tomography': 29,
#  'tissues': 29,
#  'general': 29,
#  'stratification': 29,
#  'dl': 29,
#  'markers': 29,
#  'targets': 29,
#  'proteins': 29,
#  'x': 29,
#  'crc': 29,
#  'hiv': 28,
#  '1%': 28,
#  'good': 28,
#  'postoperative': 28,
#  '88': 28,
#  'obesity': 28,
#  'strategy': 28,
#  '2020': 28,
#  'ofthe': 28,
#  '40': 28,
#  'concentrations': 28,
#  'guidelines': 28,
#  '80': 28,
#  'severity': 28,
#  'rapid': 28,
#  'discovery': 28,
#  'sequencing': 28,
#  'polyps': 28,
#  'day': 28,
#  'designed': 28,
#  'search': 28,
#  'increasing': 28,
#  'probability': 28,
#  'n': 28,
#  'records': 28,
#  'body': 28,
#  'tree': 27,
#  'enhanced': 27,
#  'external': 27,
#  'sets': 27,
#  'comprehensive': 27,
#  'demonstrate': 27,
#  'cnn': 27,
#  'before': 27,
#  'shown': 27,
#  'despite': 27,
#  'discuss': 27,
#  'improving': 27,
#  'suggest': 27,
#  'personalized': 27,
#  'china': 27,
#  '(1': 27,
#  '83': 27,
#  'computed': 27,
#  'traditional': 27,
#  'severe': 27,
#  'established': 27,
#  'interest': 27,
#  'chronic': 27,
#  'variants': 27,
#  'treatments': 27,
#  'targeted': 27,
#  '92': 27,
#  'history': 27,
#  'genome': 27,
#  'generation': 27,
#  '20': 27,
#  'pet': 27,
#  'skin': 27,
#  'false': 27,
#  '25': 26,
#  '5%': 26,
#  '9%': 26,
#  'areas': 26,
#  'contrast': 26,
#  'interpretation': 26,
#  'pathways': 26,
#  'benign': 26,
#  'malignant': 26,
#  '(ml)': 26,
#  'biomarker': 26,
#  'them': 26,
#  '15': 26,
#  'second': 26,
#  'linear': 26,
#  'furthermore': 26,
#  'aims': 26,
#  '4%': 26,
#  'report': 26,
#  'deaths': 26,
#  'like': 26,
#  'processing': 26,
#  'play': 26,
#  'estimate': 26,
#  'often': 26,
#  '7%': 26,
#  'mm': 26,
#  'so': 26,
#  '1)': 26,
#  'electronic': 26,
#  'loss': 26,
#  'rna': 26,
#  'cox': 26,
#  'possible': 26,
#  'platform': 26,
#  'challenge': 25,
#  '(auc)': 25,
#  'efforts': 25,
#  'limited': 25,
#  'modeling': 25,
#  'plasma': 25,
#  'intervention': 25,
#  '[95%': 25,
#  'million': 25,
#  'pulmonary': 25,
#  'candidate': 25,
#  'values': 25,
#  'integrated': 25,
#  'biopsy': 25,
#  'disorders': 25,
#  'needed': 25,
#  'range': 25,
#  'since': 25,
#  'article': 25,
#  'function': 25,
#  'defined': 25,
#  'melanoma': 25,
#  'global': 25,
#  'us': 25,
#  'interval': 25,
#  'automated': 25,
#  'pre': 25,
#  'estimated': 24,
#  'improvement': 24,
#  'remains': 24,
#  'worldwide': 24,
#  '100': 24,
#  'randomly': 24,
#  'still': 24,
#  'moreover': 24,
#  'planning': 24,
#  'exposure': 24,
#  'cardiovascular': 24,
#  'following': 24,
#  'six': 24,
#  'literature': 24,
#  'would': 24,
#  'explore': 24,
#  'manual': 24,
#  'way': 24,
#  'events': 24,
#  'inthe': 24,
#  'fold': 24,
#  'interactions': 24,
#  '84': 24,
#  'weight': 24,
#  'where': 24,
#  '13': 24,
#  'additionally': 24,
#  'similar': 24,
#  'because': 24,
#  'egfr': 24,
#  'according': 24,
#  '24': 24,
#  'potentially': 24,
#  'host': 23,
#  'measured': 23,
#  'any': 23,
#  'challenging': 23,
#  'validate': 23,
#  'lifestyle': 23,
#  'advanced': 23,
#  'diet': 23,
#  'unknown': 23,
#  'nodule': 23,
#  '93': 23,
#  'software': 23,
#  'vaccination': 23,
#  'al': 23,
#  '26': 23,
#  'rf': 23,
#  'include': 23,
#  'online': 23,
#  'criteria': 23,
#  'antibody': 23,
#  'processes': 23,
#  'g': 23,
#  'context': 23,
#  'family': 23,
#  'outperformed': 23,
#  '(or': 23,
#  'men': 23,
#  'csm': 23,
#  'breastcancer': 22,
#  'gradient': 22,
#  'examination': 22,
#  'phase': 22,
#  'radiomic': 22,
#  '05)': 22,
#  'recently': 22,
#  'advances': 22,
#  'main': 22,
#  'heterogeneity': 22,
#  'environmental': 22,
#  'understand': 22,
#  '55': 22,
#  '76': 22,
#  'surveillance': 22,
#  '11': 22,
#  '87': 22,
#  'caused': 22,
#  '14': 22,
#  'along': 22,
#  'employed': 22,
#  'greater': 22,
#  '17': 22,
#  'pathologists': 22,
#  'investigate': 22,
#  '2018': 22,
#  'published': 22,
#  'point': 22,
#  'prevent': 22,
#  'problems': 22,
#  'effectiveness': 22,
#  'analytics': 22,
#  'reduced': 22,
#  'compare': 22,
#  'whole': 22,
#  '74': 22,
#  'allow': 22,
#  'user': 22,
#  'heterogeneous': 22,
#  'reading': 22,
#  'thyroid': 22,
#  'relative': 21,
#  'last': 21,
#  'adjusted': 21,
#  'great': 21,
#  'b': 21,
#  'subtypes': 21,
#  'materials': 21,
#  '60': 21,
#  'radiotherapy': 21,
#  'benefit': 21,
#  'supervised': 21,
#  'relevance': 21,
#  'united': 21,
#  'difference': 21,
#  '16': 21,
#  'appropriate': 21,
#  'survey': 21,
#  'biomedical': 21,
#  'discussed': 21,
#  'receptor': 21,
#  '79': 21,
#  'essential': 21,
#  'activation': 21,
#  'retrospective': 21,
#  'reference': 21,
#  'inform': 21,
#  'researchers': 21,
#  'conditions': 21,
#  'cvd': 21,
#  '8%': 21,
#  'built': 21,
#  'art': 21,
#  'ky': 21,
#  'stress': 21,
#  'mutation': 21,
#  'less': 21,
#  'structure': 21,
#  'categories': 21,
#  'reports': 21,
#  'settings': 21,
#  'operator': 21,
#  'percentage': 21,
#  'considered': 20,
#  'highly': 20,
#  'pathway': 20,
#  '95': 20,
#  'poor': 20,
#  'constructed': 20,
#  'revealed': 20,
#  'normal': 20,
#  'causes': 20,
#  'emerging': 20,
#  'artificialintelligence': 20,
#  'few': 20,
#  'occurrence': 20,
#  'make': 20,
#  '000': 20,
#  'change': 20,
#  'investigated': 20,
#  '75': 20,
#  'decreased': 20,
#  'assisted': 20,
#  'driven': 20,
#  'adenocarcinoma': 20,
#  'end': 20,
#  'expected': 20,
#  'stages': 20,
#  'consuming': 20,
#  'period': 20,
#  'commonly': 20,
#  'estimates': 20,
#  'stained': 20,
#  'examined': 20,
#  'wide': 20,
#  'web': 20,
#  'acid': 20,
#  'molecules': 20,
#  '(e': 20,
#  '81': 20,
#  'relapse': 20,
#  'calculated': 20,
#  'integration': 20,
#  'chemotherapy': 20,
#  'big': 20,
#  '(2)': 20,
#  'domain': 20,
#  'lncrna': 20,
#  'indexes': 20,
#  'roc': 19,
#  'towards': 19,
#  'efficient': 19,
#  'extract': 19,
#  'presented': 19,
#  'pathological': 19,
#  'component': 19,
#  'gc': 19,
#  'very': 19,
#  'distinguish': 19,
#  'objectives': 19,
#  'january': 19,
#  'facilitate': 19,
#  'clinicians': 19,
#  'days': 19,
#  'visual': 19,
#  'cellular': 19,
#  'endometrial': 19,
#  'significance': 19,
#  'growing': 19,
#  'local': 19,
#  'signature': 19,
#  'alone': 19,
#  '85': 19,
#  'part': 19,
#  'previously': 19,
#  'stroke': 19,
#  'absolute': 19,
#  'nodes': 19,
#  'implemented': 19,
#  'text': 19,
#  'enable': 19,
#  'cognitive': 19,
#  'extraction': 19,
#  'compounds': 19,
#  'donor': 19,
#  'lasso': 19,
#  'self': 19,
#  'cytology': 19,
#  'median': 19,
#  'bone': 19,
#  'metastases': 19,
#  'pca': 19,
#  'cad': 19,
#  'responses': 18,
#  'nine': 18,
#  '72': 18,
#  '53': 18,
#  'power': 18,
#  'free': 18,
#  'efficiency': 18,
#  'divided': 18,
#  "patients'": 18,
#  'density': 18,
#  'goal': 18,
#  'scientific': 18,
#  'basis': 18,
#  'k': 18,
#  'spectrometry': 18,
#  'measure': 18,
#  '78': 18,
#  'states': 18,
#  'ovarian': 18,
#  '(svm)': 18,
#  '91': 18,
#  'superior': 18,
#  'profiles': 18,
#  'admission': 18,
#  'people': 18,
#  'slides': 18,
#  'shows': 18,
#  'original': 18,
#  'clinic': 18,
#  'involved': 18,
#  '100%': 18,
#  'sequence': 18,
#  'pd': 18,
#  'problem': 18,
#  'recall': 18,
#  'physical': 18,
#  'radiologists': 18,
#  'systematic': 18,
#  'routine': 18,
#  'center': 18,
#  'community': 18,
#  'interaction': 18,
#  '66': 18,
#  'unique': 18,
#  'r': 18,
#  'abnormal': 18,
#  'urine': 18,
#  '2016': 18,
#  'classify': 18,
#  'step': 18,
#  '(auc': 18,
#  'tracking': 18,
#  'topics': 18,
#  '27': 18,
#  'endometriosis': 18,
#  'variable': 17,
#  ...}

# %%
# try to remove the most common english words
dfs = pd.read_html('https://en.wikipedia.org/wiki/Most_common_words_in_English')

# %%
common = pd.read_csv('Untitled 1.csv', header=None)
common = common[0].tolist()

# %%
common_worlds = dfs[0]['Word'].tolist()
common = common + common_worlds

# %%
cleaned_dict = dic.copy()

# %%
for key, value in dic.items():
    if key in common:
        del cleaned_dict[key]

# %%
# still a lot of trash
# need other method to clean it better otherwise not useful
cleaned_dict
# Out:
# {'0': 933,
#  'cancer': 914,
#  'learning': 564,
#  'model': 555,
#  'patients': 534,
#  'data': 496,
#  'risk': 474,
#  'machine': 447,
#  'based': 442,
#  'using': 396,
#  'results': 384,
#  'clinical': 350,
#  'models': 346,
#  'methods': 344,
#  '1': 343,
#  'used': 303,
#  '2': 253,
#  'analysis': 248,
#  'disease': 231,
#  'prediction': 229,
#  'accuracy': 217,
#  'treatment': 217,
#  'features': 215,
#  'breast': 208,
#  'prevention': 202,
#  'performance': 199,
#  'health': 190,
#  'tumor': 183,
#  'method': 176,
#  'diagnosis': 175,
#  'detection': 166,
#  '3': 149,
#  'research': 146,
#  'associated': 146,
#  'deep': 146,
#  'patient': 144,
#  'identify': 144,
#  'images': 144,
#  'potential': 142,
#  'factors': 142,
#  'validation': 140,
#  'screening': 138,
#  '19': 136,
#  'compared': 134,
#  'predictive': 134,
#  'related': 132,
#  'ai': 132,
#  'background': 131,
#  'lung': 131,
#  'network': 129,
#  'developed': 129,
#  'algorithms': 129,
#  'however': 128,
#  'classification': 127,
#  'information': 125,
#  'algorithm': 125,
#  'system': 125,
#  'predict': 125,
#  'covid': 125,
#  'cell': 123,
#  'including': 123,
#  'sensitivity': 123,
#  'early': 123,
#  'survival': 122,
#  'ci': 120,
#  'test': 120,
#  'conclusions': 118,
#  'identified': 117,
#  'age': 117,
#  'p': 117,
#  'studies': 114,
#  'imaging': 114,
#  'genes': 113,
#  'low': 111,
#  'approach': 109,
#  'showed': 105,
#  'diseases': 103,
#  'support': 103,
#  '5': 102,
#  'specific': 100,
#  'development': 100,
#  'respectively': 99,
#  'specificity': 99,
#  'mortality': 99,
#  'regression': 98,
#  'cohort': 98,
#  'training': 98,
#  'value': 97,
#  'cases': 97,
#  'among': 96,
#  'care': 96,
#  'women': 95,
#  'score': 95,
#  'proposed': 95,
#  'primary': 92,
#  'gene': 91,
#  'conclusion': 90,
#  'evaluated': 90,
#  'outcomes': 89,
#  'curve': 89,
#  'random': 89,
#  '<': 89,
#  'develop': 88,
#  'neural': 88,
#  'improve': 87,
#  'testing': 87,
#  'medical': 87,
#  'predicting': 86,
#  'higher': 85,
#  'cells': 85,
#  'expression': 84,
#  'years': 84,
#  'human': 83,
#  'image': 83,
#  '95%': 83,
#  'total': 82,
#  'provide': 82,
#  'tool': 82,
#  '4': 82,
#  '(n': 82,
#  'biomarkers': 82,
#  'ml': 82,
#  'non': 81,
#  'forest': 81,
#  'prognostic': 81,
#  'ct': 81,
#  'immune': 80,
#  'samples': 80,
#  'significantly': 80,
#  'area': 79,
#  'medicine': 78,
#  'auc': 77,
#  'diagnostic': 77,
#  '6': 77,
#  'type': 77,
#  'dose': 76,
#  '(0': 76,
#  'further': 76,
#  'precision': 76,
#  'feature': 76,
#  'decision': 76,
#  'effective': 76,
#  'techniques': 76,
#  'cervical': 76,
#  'role': 75,
#  'datasets': 75,
#  'rate': 75,
#  'cov': 75,
#  'level': 74,
#  'significant': 74,
#  'drug': 74,
#  'selection': 74,
#  '(p': 73,
#  'liver': 71,
#  'included': 70,
#  'artificial': 70,
#  'intelligence': 70,
#  'review': 70,
#  '10': 69,
#  'approaches': 68,
#  'novel': 68,
#  'stage': 68,
#  'due': 67,
#  'tissue': 67,
#  'status': 66,
#  'best': 66,
#  'performed': 66,
#  'findings': 65,
#  'overall': 65,
#  'cancers': 65,
#  'hospital': 65,
#  'dataset': 65,
#  'participants': 64,
#  'therapy': 64,
#  '+': 64,
#  'applied': 64,
#  'future': 63,
#  'selected': 63,
#  'current': 63,
#  'within': 62,
#  't': 62,
#  'several': 62,
#  'positive': 61,
#  'variables': 61,
#  'prognosis': 61,
#  'population': 61,
#  'activity': 61,
#  'achieved': 60,
#  'genetic': 60,
#  '001)': 60,
#  'sars': 60,
#  'vs': 60,
#  'objective': 60,
#  'single': 60,
#  'response': 59,
#  'molecular': 59,
#  '7': 58,
#  'evaluate': 58,
#  '8': 58,
#  'management': 58,
#  'systems': 58,
#  '(95%': 57,
#  'across': 57,
#  'blood': 57,
#  'factor': 57,
#  'strategies': 57,
#  'available': 57,
#  'multi': 57,
#  'types': 57,
#  'application': 57,
#  'cross': 56,
#  'accurate': 56,
#  'pathology': 56,
#  'individual': 55,
#  'obtained': 55,
#  'assessment': 55,
#  'validated': 54,
#  'predictors': 54,
#  'analyses': 54,
#  'negative': 54,
#  'analyzed': 54,
#  'index': 54,
#  'vector': 54,
#  'average': 53,
#  'rates': 53,
#  'improved': 53,
#  'infection': 53,
#  'able': 53,
#  'various': 53,
#  'identification': 52,
#  'aim': 52,
#  'increased': 52,
#  'purpose': 52,
#  'present': 52,
#  'control': 52,
#  'characteristics': 51,
#  'during': 51,
#  'trained': 51,
#  'key': 51,
#  'increase': 51,
#  'case': 51,
#  'better': 51,
#  'progression': 50,
#  'levels': 50,
#  'common': 50,
#  'colorectal': 50,
#  'effect': 49,
#  'tools': 49,
#  'recurrence': 49,
#  'quality': 49,
#  'public': 49,
#  'multiple': 49,
#  'evaluation': 49,
#  '12': 48,
#  'collected': 48,
#  'groups': 48,
#  '9': 48,
#  'demonstrated': 48,
#  'hpv': 48,
#  'carcinoma': 47,
#  'combination': 47,
#  'e': 47,
#  'digital': 47,
#  'knowledge': 47,
#  'effects': 47,
#  'vaccine': 46,
#  'importance': 46,
#  'radiomics': 46,
#  'changes': 46,
#  'known': 46,
#  'omics': 46,
#  'metastasis': 46,
#  'challenges': 46,
#  'prostate': 46,
#  'machinelearning': 45,
#  'grade': 45,
#  'lesions': 45,
#  'protein': 45,
#  'upon': 45,
#  'trials': 44,
#  'independent': 44,
#  'quantitative': 44,
#  'outcome': 44,
#  'individuals': 44,
#  'parameters': 44,
#  'mass': 44,
#  'understanding': 44,
#  'incidence': 44,
#  'applications': 44,
#  'computational': 43,
#  'observed': 43,
#  'scores': 43,
#  'classifier': 43,
#  'existing': 43,
#  'provides': 43,
#  'practice': 43,
#  'making': 42,
#  'receiver': 42,
#  'technology': 42,
#  'ability': 42,
#  'five': 42,
#  'technologies': 42,
#  'recent': 42,
#  'tumors': 41,
#  'leading': 41,
#  'logistic': 41,
#  'extracted': 41,
#  'surgery': 41,
#  'oral': 41,
#  'u': 41,
#  'although': 41,
#  'design': 41,
#  'university': 41,
#  'database': 41,
#  'impact': 41,
#  'process': 40,
#  'operating': 40,
#  'cause': 40,
#  'standard': 40,
#  'least': 40,
#  'volume': 40,
#  'mechanisms': 40,
#  'i': 40,
#  'sample': 40,
#  'major': 39,
#  'determine': 39,
#  'identifying': 39,
#  'characteristic': 39,
#  'monitoring': 39,
#  'nodules': 39,
#  'completion': 39,
#  'tests': 39,
#  'complex': 39,
#  'conducted': 38,
#  'assessed': 38,
#  '50': 38,
#  'lower': 38,
#  'gastric': 38,
#  'critical': 38,
#  'field': 38,
#  'ratio': 38,
#  'evidence': 38,
#  'trial': 38,
#  'cost': 38,
#  'promising': 38,
#  'developing': 38,
#  'lymph': 38,
#  'detect': 38,
#  'hcc': 38,
#  'pancreatic': 38,
#  'aimed': 37,
#  '2%': 37,
#  'scale': 37,
#  'derived': 37,
#  'biological': 37,
#  'addition': 37,
#  'combined': 37,
#  'oncology': 37,
#  'healthcare': 37,
#  'result': 37,
#  'optimal': 37,
#  'predicted': 37,
#  '>': 37,
#  '%': 37,
#  'real': 37,
#  'assay': 36,
#  'versus': 36,
#  'setting': 36,
#  'diagnosed': 36,
#  'months': 36,
#  'finally': 36,
#  'net': 36,
#  'therefore': 36,
#  'per': 36,
#  'networks': 36,
#  'anti': 36,
#  'louisville': 36,
#  'size': 35,
#  'framework': 35,
#  'death': 35,
#  'term': 35,
#  'therapeutic': 35,
#  'highest': 35,
#  'drugs': 34,
#  'convolutional': 34,
#  'smoking': 34,
#  'presence': 34,
#  'radiation': 34,
#  '2019': 34,
#  'controls': 34,
#  'virus': 34,
#  'pandemic': 34,
#  'reduce': 34,
#  'segmentation': 34,
#  'measures': 34,
#  'associations': 34,
#  'useful': 34,
#  'generated': 34,
#  'svm': 34,
#  'node': 34,
#  'metabolic': 34,
#  'pain': 34,
#  'healthy': 34,
#  'tested': 34,
#  '30': 33,
#  'genomic': 33,
#  'association': 33,
#  'mri': 33,
#  'differences': 33,
#  'whether': 33,
#  'thus': 33,
#  'error': 33,
#  'statistical': 32,
#  'relevant': 32,
#  'given': 32,
#  'diabetes': 32,
#  'via': 32,
#  'social': 32,
#  'efficacy': 32,
#  'describe': 32,
#  'panel': 32,
#  'reduction': 32,
#  'invasive': 32,
#  'especially': 32,
#  '90': 32,
#  'assess': 31,
#  'post': 31,
#  'national': 31,
#  'currently': 31,
#  'previous': 31,
#  'experimental': 31,
#  'followed': 31,
#  '(ai)': 31,
#  'become': 31,
#  'utility': 31,
#  'growth': 31,
#  'computer': 31,
#  'top': 31,
#  'focus': 31,
#  '0%': 31,
#  'acute': 31,
#  'dna': 31,
#  'implementation': 31,
#  'provided': 31,
#  'interventions': 31,
#  'robust': 31,
#  'having': 31,
#  'reported': 31,
#  'patterns': 30,
#  'predictions': 30,
#  'confirmed': 30,
#  'cohorts': 30,
#  'correlation': 30,
#  'target': 30,
#  'symptoms': 30,
#  's': 30,
#  '3%': 30,
#  'vaccines': 30,
#  'additional': 30,
#  'c': 30,
#  'prior': 30,
#  'laboratory': 30,
#  'regions': 30,
#  '3d': 30,
#  'baseline': 29,
#  'propose': 29,
#  'classifiers': 29,
#  'against': 29,
#  'order': 29,
#  'clinically': 29,
#  'burden': 29,
#  'ensemble': 29,
#  'colonoscopy': 29,
#  'tomography': 29,
#  'tissues': 29,
#  'general': 29,
#  'stratification': 29,
#  'dl': 29,
#  'markers': 29,
#  'targets': 29,
#  'proteins': 29,
#  'x': 29,
#  'crc': 29,
#  'hiv': 28,
#  '1%': 28,
#  'postoperative': 28,
#  '88': 28,
#  'obesity': 28,
#  'strategy': 28,
#  '2020': 28,
#  'ofthe': 28,
#  '40': 28,
#  'concentrations': 28,
#  'guidelines': 28,
#  '80': 28,
#  'severity': 28,
#  'rapid': 28,
#  'discovery': 28,
#  'sequencing': 28,
#  'polyps': 28,
#  'designed': 28,
#  'search': 28,
#  'increasing': 28,
#  'probability': 28,
#  'n': 28,
#  'records': 28,
#  'body': 28,
#  'enhanced': 27,
#  'external': 27,
#  'sets': 27,
#  'comprehensive': 27,
#  'demonstrate': 27,
#  'cnn': 27,
#  'shown': 27,
#  'despite': 27,
#  'discuss': 27,
#  'improving': 27,
#  'suggest': 27,
#  'personalized': 27,
#  'china': 27,
#  '(1': 27,
#  '83': 27,
#  'computed': 27,
#  'traditional': 27,
#  'severe': 27,
#  'established': 27,
#  'interest': 27,
#  'chronic': 27,
#  'variants': 27,
#  'treatments': 27,
#  'targeted': 27,
#  '92': 27,
#  'history': 27,
#  'genome': 27,
#  'generation': 27,
#  '20': 27,
#  'pet': 27,
#  'skin': 27,
#  'false': 27,
#  '25': 26,
#  '5%': 26,
#  '9%': 26,
#  'areas': 26,
#  'contrast': 26,
#  'interpretation': 26,
#  'pathways': 26,
#  'benign': 26,
#  'malignant': 26,
#  '(ml)': 26,
#  'biomarker': 26,
#  '15': 26,
#  'linear': 26,
#  'furthermore': 26,
#  'aims': 26,
#  '4%': 26,
#  'report': 26,
#  'deaths': 26,
#  'processing': 26,
#  'estimate': 26,
#  '7%': 26,
#  'mm': 26,
#  '1)': 26,
#  'electronic': 26,
#  'loss': 26,
#  'rna': 26,
#  'cox': 26,
#  'possible': 26,
#  'platform': 26,
#  'challenge': 25,
#  '(auc)': 25,
#  'efforts': 25,
#  'limited': 25,
#  'modeling': 25,
#  'plasma': 25,
#  'intervention': 25,
#  '[95%': 25,
#  'million': 25,
#  'pulmonary': 25,
#  'candidate': 25,
#  'values': 25,
#  'integrated': 25,
#  'biopsy': 25,
#  'disorders': 25,
#  'needed': 25,
#  'range': 25,
#  'since': 25,
#  'article': 25,
#  'function': 25,
#  'defined': 25,
#  'melanoma': 25,
#  'global': 25,
#  'interval': 25,
#  'automated': 25,
#  'pre': 25,
#  'estimated': 24,
#  'improvement': 24,
#  'remains': 24,
#  'worldwide': 24,
#  '100': 24,
#  'randomly': 24,
#  'moreover': 24,
#  'planning': 24,
#  'exposure': 24,
#  'cardiovascular': 24,
#  'following': 24,
#  'six': 24,
#  'literature': 24,
#  'explore': 24,
#  'manual': 24,
#  'events': 24,
#  'inthe': 24,
#  'fold': 24,
#  'interactions': 24,
#  '84': 24,
#  'weight': 24,
#  '13': 24,
#  'additionally': 24,
#  'similar': 24,
#  'egfr': 24,
#  'according': 24,
#  '24': 24,
#  'potentially': 24,
#  'host': 23,
#  'measured': 23,
#  'challenging': 23,
#  'validate': 23,
#  'lifestyle': 23,
#  'advanced': 23,
#  'diet': 23,
#  'unknown': 23,
#  'nodule': 23,
#  '93': 23,
#  'software': 23,
#  'vaccination': 23,
#  'al': 23,
#  '26': 23,
#  'rf': 23,
#  'include': 23,
#  'online': 23,
#  'criteria': 23,
#  'antibody': 23,
#  'processes': 23,
#  'g': 23,
#  'context': 23,
#  'outperformed': 23,
#  '(or': 23,
#  'csm': 23,
#  'breastcancer': 22,
#  'gradient': 22,
#  'examination': 22,
#  'phase': 22,
#  'radiomic': 22,
#  '05)': 22,
#  'recently': 22,
#  'advances': 22,
#  'main': 22,
#  'heterogeneity': 22,
#  'environmental': 22,
#  'understand': 22,
#  '55': 22,
#  '76': 22,
#  'surveillance': 22,
#  '11': 22,
#  '87': 22,
#  'caused': 22,
#  '14': 22,
#  'employed': 22,
#  'greater': 22,
#  '17': 22,
#  'pathologists': 22,
#  'investigate': 22,
#  '2018': 22,
#  'published': 22,
#  'prevent': 22,
#  'problems': 22,
#  'effectiveness': 22,
#  'analytics': 22,
#  'reduced': 22,
#  'compare': 22,
#  'whole': 22,
#  '74': 22,
#  'allow': 22,
#  'user': 22,
#  'heterogeneous': 22,
#  'reading': 22,
#  'thyroid': 22,
#  'relative': 21,
#  'adjusted': 21,
#  'b': 21,
#  'subtypes': 21,
#  'materials': 21,
#  '60': 21,
#  'radiotherapy': 21,
#  'benefit': 21,
#  'supervised': 21,
#  'relevance': 21,
#  'united': 21,
#  'difference': 21,
#  '16': 21,
#  'appropriate': 21,
#  'survey': 21,
#  'biomedical': 21,
#  'discussed': 21,
#  'receptor': 21,
#  '79': 21,
#  'essential': 21,
#  'activation': 21,
#  'retrospective': 21,
#  'reference': 21,
#  'inform': 21,
#  'researchers': 21,
#  'conditions': 21,
#  'cvd': 21,
#  '8%': 21,
#  'built': 21,
#  'art': 21,
#  'ky': 21,
#  'stress': 21,
#  'mutation': 21,
#  'less': 21,
#  'structure': 21,
#  'categories': 21,
#  'reports': 21,
#  'settings': 21,
#  'operator': 21,
#  'percentage': 21,
#  'considered': 20,
#  'highly': 20,
#  'pathway': 20,
#  '95': 20,
#  'poor': 20,
#  'constructed': 20,
#  'revealed': 20,
#  'normal': 20,
#  'causes': 20,
#  'emerging': 20,
#  'artificialintelligence': 20,
#  'occurrence': 20,
#  '000': 20,
#  'investigated': 20,
#  '75': 20,
#  'decreased': 20,
#  'assisted': 20,
#  'driven': 20,
#  'adenocarcinoma': 20,
#  'expected': 20,
#  'stages': 20,
#  'consuming': 20,
#  'period': 20,
#  'commonly': 20,
#  'estimates': 20,
#  'stained': 20,
#  'examined': 20,
#  'wide': 20,
#  'web': 20,
#  'acid': 20,
#  'molecules': 20,
#  '(e': 20,
#  '81': 20,
#  'relapse': 20,
#  'calculated': 20,
#  'integration': 20,
#  'chemotherapy': 20,
#  '(2)': 20,
#  'domain': 20,
#  'lncrna': 20,
#  'indexes': 20,
#  'roc': 19,
#  'towards': 19,
#  'efficient': 19,
#  'extract': 19,
#  'presented': 19,
#  'pathological': 19,
#  'component': 19,
#  'gc': 19,
#  'distinguish': 19,
#  'objectives': 19,
#  'january': 19,
#  'facilitate': 19,
#  'clinicians': 19,
#  'days': 19,
#  'visual': 19,
#  'cellular': 19,
#  'endometrial': 19,
#  'significance': 19,
#  'growing': 19,
#  'local': 19,
#  'signature': 19,
#  'alone': 19,
#  '85': 19,
#  'previously': 19,
#  'stroke': 19,
#  'absolute': 19,
#  'nodes': 19,
#  'implemented': 19,
#  'text': 19,
#  'enable': 19,
#  'cognitive': 19,
#  'extraction': 19,
#  'compounds': 19,
#  'donor': 19,
#  'lasso': 19,
#  'self': 19,
#  'cytology': 19,
#  'median': 19,
#  'bone': 19,
#  'metastases': 19,
#  'pca': 19,
#  'cad': 19,
#  'responses': 18,
#  'nine': 18,
#  '72': 18,
#  '53': 18,
#  'power': 18,
#  'free': 18,
#  'efficiency': 18,
#  'divided': 18,
#  "patients'": 18,
#  'density': 18,
#  'goal': 18,
#  'scientific': 18,
#  'basis': 18,
#  'k': 18,
#  'spectrometry': 18,
#  'measure': 18,
#  '78': 18,
#  'states': 18,
#  'ovarian': 18,
#  '(svm)': 18,
#  '91': 18,
#  'superior': 18,
#  'profiles': 18,
#  'admission': 18,
#  'slides': 18,
#  'shows': 18,
#  'original': 18,
#  'clinic': 18,
#  'involved': 18,
#  '100%': 18,
#  'sequence': 18,
#  'pd': 18,
#  'problem': 18,
#  'recall': 18,
#  'physical': 18,
#  'radiologists': 18,
#  'systematic': 18,
#  'routine': 18,
#  'center': 18,
#  'community': 18,
#  'interaction': 18,
#  '66': 18,
#  'unique': 18,
#  'r': 18,
#  'abnormal': 18,
#  'urine': 18,
#  '2016': 18,
#  'classify': 18,
#  'step': 18,
#  '(auc': 18,
#  'tracking': 18,
#  'topics': 18,
#  '27': 18,
#  'endometriosis': 18,
#  'variable': 17,
#  'collection': 17,
#  'sources': 17,
#  'class': 17,
#  'ii': 17,
#  'boosting': 17,
#  'exhibited': 17,
#  'mrna': 17,
#  'required': 17,
#  '71': 17,
#  'institutions': 17,
#  'sites': 17,
#  'lesion': 17,
#  'decisions': 17,
#  'build': 17,
#  'clustering': 17,
#  'signatures': 17,
#  '77': 17,
#  'short': 17,
#  'whereas': 17,
#  'adenoma': 17,
#  '96': 17,
#  'treated': 17,
#  'enriched': 17,
#  'icu': 17,
#  'task': 17,
#  'achieve': 17,
#  '89': 17,
#  'powerful': 17,
#  'diagnoses': 17,
#  'chest': 17,
#  'methylation': 17,
#  'classified': 17,
#  'environment': 17,
#  'introduction': 17,
#  'lack': 17,
#  'influence': 17,
#  'full': 17,
#  'containing': 17,
#  'program': 17,
#  '33': 17,
#  'm': 17,
#  'either': 17,
#  'circulating': 17,
#  'marker': 17,
#  'address': 17,
#  'science': 17,
#  'called': 17,
#  'predictor': 17,
#  'luad': 17,
#  'articles': 17,
#  'methodology': 17,
#  '23': 17,
#  'metrics': 17,
#  'dependent': 17,
#  'subset': 17,
#  'ldct': 17,
#  'beam': 17,
#  'odx': 17,
#  'tweets': 17,
#  'contribute': 16,
#  'utilized': 16,
#  '94': 16,
#  'calibration': 16,
#  '22': 16,
#  'andthe': 16,
#  'conventional': 16,
#  'ad': 16,
#  'surgical': 16,
#  'coefficient': 16,
#  'distribution': 16,
#  'crucial': 16,
#  'recovery': 16,
#  'toidentify': 16,
#  'polyp': 16,
#  'damage': 16,
#  'dysfunction': 16,
#  'approved': 16,
#  'remain': 16,
#  'slide': 16,
#  'providing': 16,
#  'databases': 16,
#  '<0': 16,
#  'older': 16,
#  'detected': 16,
#  '86': 16,
#  'recognize': 16,
#  'investigation': 16,
#  'reducing': 16,
#  'widely': 16,
#  'lymphedema': 16,
#  'final': 16,
#  'underlying': 16,
#  'examine': 16,
#  '2)': 16,
#  'month': 16,
#  'technique': 16,
#  'suggests': 16,
#  'analytical': 16,
#  'sepsis': 16,
#  'recognition': 16,
#  'mining': 16,
#  'service': 16,
#  'h': 16,
#  'train': 16,
#  'functional': 16,
#  ')': 16,
#  'generate': 16,
#  'et': 16,
#  '56': 16,
#  'microbiome': 16,
#  'her2': 16,
#  'availability': 15,
#  'igg': 15,
#  '73': 15,
#  '69': 15,
#  '63': 15,
#  'birth': 15,
#  'guide': 15,
#  'hence': 15,
#  'map': 15,
#  'analyze': 15,
#  'received': 15,
#  'accurately': 15,
#  'implications': 15,
#  'construct': 15,
#  'f1': 15,
#  'linked': 15,
#  'comparing': 15,
#  'underwent': 15,
#  'european': 15,
#  'fully': 15,
#  '(95': 15,
#  'sections': 15,
#  'assist': 15,
#  'created': 15,
#  'apa': 15,
#  ...}

# %%
most_common_abstract = list(cleaned_dict.keys())[0:10]

# %% [markdown]
# <a id='section_id5'></a>

# %% [markdown]
# # Automatic dictionary from keywords

# %%
keywords = df['keywords'].tolist()
dic = {}
for keys in keywords:
    dic = word_freq(keys, dic)
    
dic = {key: val for key, 
       val in sorted(dic.items(), 
       key = lambda ele: ele[1], reverse = True)}

# %%
dic
# Out:
# {'learning': 462,
#  'machine': 376,
#  'humans': 347,
#  'methods': 277,
#  'neoplasms': 240,
#  'cancer': 208,
#  'diagnosis': 201,
#  'imaging': 185,
#  'genetics': 180,
#  'pathology': 180,
#  'diagnostic': 157,
#  'prevention': 153,
#  'aged': 148,
#  'control': 141,
#  'of': 139,
#  'computer': 133,
#  'female': 132,
#  'deep': 130,
#  'risk': 128,
#  'epidemiology': 108,
#  'studies': 106,
#  'analysis': 106,
#  'therapy': 97,
#  'data': 95,
#  'breast': 94,
#  'artificial': 90,
#  'drug': 87,
#  'metabolism': 86,
#  'middle': 83,
#  'intelligence': 82,
#  'male': 75,
#  'disease': 73,
#  'neural': 72,
#  'and': 72,
#  'cell': 70,
#  'assisted': 69,
#  'lung': 68,
#  'adult': 67,
#  'algorithms': 66,
#  'factors': 66,
#  'tomography': 65,
#  'tumor': 64,
#  'health': 64,
#  'biomarkers': 63,
#  'image': 61,
#  'models': 60,
#  'immunology': 60,
#  'networks': 57,
#  'computed': 57,
#  'detection': 57,
#  'neoplasm': 56,
#  'effects': 55,
#  'support': 54,
#  'prognosis': 53,
#  'assessment': 51,
#  'early': 50,
#  'medicine': 50,
#  'covid': 49,
#  '19': 49,
#  'curve': 48,
#  'gene': 48,
#  'statistics': 47,
#  'retrospective': 44,
#  'chemistry': 44,
#  'carcinoma': 43,
#  'vector': 43,
#  'blood': 43,
#  'classification': 42,
#  'numerical': 41,
#  'prediction': 40,
#  'x': 40,
#  'expression': 40,
#  'genetic': 40,
#  'etiology': 39,
#  'colorectal': 39,
#  'mortality': 38,
#  'ray': 38,
#  'surgery': 37,
#  'biology': 37,
#  'precision': 37,
#  'radiotherapy': 36,
#  'processing': 36,
#  'screening': 36,
#  'cervical': 36,
#  'diseases': 36,
#  'radiation': 34,
#  '2': 34,
#  'computational': 34,
#  'therapeutic': 34,
#  'use': 33,
#  'survival': 33,
#  'network': 32,
#  'mass': 32,
#  'roc': 31,
#  'adverse': 30,
#  'protein': 30,
#  'trends': 30,
#  'decision': 29,
#  'liver': 28,
#  'reproducibility': 28,
#  'care': 28,
#  'results': 27,
#  'clinical': 27,
#  'recurrence': 27,
#  'vaccines': 26,
#  'predictive': 26,
#  'model': 25,
#  'complications': 24,
#  'agents': 23,
#  'virology': 23,
#  'sensitivity': 22,
#  'specificity': 22,
#  'rna': 22,
#  'treatment': 22,
#  'interpretation': 22,
#  'dna': 21,
#  'patient': 21,
#  'neoplastic': 21,
#  'tests': 21,
#  'sequence': 21,
#  'sars': 20,
#  'cov': 20,
#  'animals': 20,
#  'infections': 20,
#  'metastasis': 20,
#  'biopsy': 20,
#  'muscle': 20,
#  'magnetic': 19,
#  'area': 19,
#  'under': 19,
#  'medical': 19,
#  'as': 19,
#  'topic': 19,
#  'local': 19,
#  'value': 19,
#  'resonance': 18,
#  'oncology': 18,
#  'uterine': 18,
#  'antineoplastic': 18,
#  'stem': 18,
#  'pharmacology': 18,
#  'databases': 18,
#  'systems': 17,
#  'pulmonary': 17,
#  'papillomavirus': 17,
#  'aging': 17,
#  'simulation': 17,
#  'statistical': 17,
#  'profiling': 17,
#  'vaccine': 16,
#  'radiomics': 16,
#  'random': 16,
#  'chronic': 16,
#  'cohort': 16,
#  'to': 16,
#  'regulation': 16,
#  'factor': 16,
#  'proteins': 16,
#  't': 15,
#  'bayes': 15,
#  'virus': 15,
#  'stomach': 15,
#  'cardiovascular': 15,
#  'selection': 15,
#  'electronic': 15,
#  'united': 15,
#  'microbiology': 15,
#  'young': 15,
#  'standards': 15,
#  'biological': 14,
#  'feature': 14,
#  'metabolomics': 14,
#  'adenocarcinoma': 14,
#  'life': 14,
#  'pancreatic': 14,
#  'physiology': 14,
#  'forest': 14,
#  'cells': 14,
#  'multi': 14,
#  'predisposition': 14,
#  'hepatocellular': 13,
#  'theorem': 13,
#  'viral': 13,
#  'public': 13,
#  'non': 13,
#  'lymphocytes': 13,
#  'proteomics': 13,
#  'child': 13,
#  'research': 13,
#  'records': 13,
#  'hiv': 13,
#  'prostatic': 13,
#  'states': 13,
#  'social': 13,
#  'urine': 13,
#  'genomics': 13,
#  'mining': 13,
#  'staging': 13,
#  'psychology': 13,
#  'mitochondrial': 13,
#  '1': 13,
#  'human': 12,
#  'stratification': 12,
#  'diabetes': 12,
#  'antibodies': 12,
#  'transplantation': 12,
#  'forecasting': 12,
#  'incidence': 12,
#  'chemotherapy': 12,
#  'skin': 12,
#  'software': 12,
#  'time': 12,
#  'single': 12,
#  'association': 12,
#  'errors': 12,
#  'media': 11,
#  'squamous': 11,
#  'spectrometry': 11,
#  'diet': 11,
#  'personalized': 11,
#  'the': 11,
#  'vaccination': 11,
#  'convolutional': 11,
#  'polyps': 11,
#  'colonoscopy': 11,
#  'index': 11,
#  'c': 11,
#  'pandemics': 11,
#  'logistic': 11,
#  'related': 11,
#  'receptor': 11,
#  'tissue': 11,
#  'study': 11,
#  'prospective': 11,
#  'multiple': 11,
#  'datasets': 11,
#  'up': 11,
#  'planning': 11,
#  'techniques': 10,
#  'cluster': 10,
#  'digital': 10,
#  'algorithm': 10,
#  'modeling': 10,
#  'lymphatic': 10,
#  'mammography': 10,
#  'receptors': 10,
#  'adolescent': 10,
#  'pain': 10,
#  'in': 10,
#  '80': 10,
#  'over': 10,
#  'molecular': 10,
#  'theoretical': 10,
#  'radiographic': 10,
#  'factual': 10,
#  'big': 10,
#  'follow': 10,
#  'case': 10,
#  'response': 9,
#  'science': 9,
#  'nutrition': 9,
#  'aided': 9,
#  'gastric': 9,
#  'colonic': 9,
#  'esophageal': 9,
#  'lymph': 9,
#  'genome': 9,
#  'outcome': 9,
#  'high': 9,
#  'nucleotide': 9,
#  'obesity': 9,
#  'making': 9,
#  'mutation': 9,
#  'growth': 9,
#  'prostate': 9,
#  'quality': 9,
#  'exercise': 9,
#  'spinal': 9,
#  'dosage': 9,
#  'nodule': 9,
#  'emission': 9,
#  'ct': 9,
#  'acid': 9,
#  'circulating': 9,
#  'rate': 9,
#  'line': 8,
#  'raman': 8,
#  'discovery': 8,
#  'oral': 8,
#  'coronavirus': 8,
#  'renal': 8,
#  'postoperative': 8,
#  'mice': 8,
#  'management': 8,
#  'type': 8,
#  'primary': 8,
#  'positive': 8,
#  'omics': 8,
#  'regression': 8,
#  'natural': 8,
#  'micrornas': 8,
#  'small': 8,
#  'erbb': 8,
#  'water': 8,
#  'induced': 8,
#  'china': 8,
#  'microenvironment': 8,
#  'score': 8,
#  'inhibitors': 8,
#  'free': 8,
#  'secondary': 8,
#  'epithelial': 8,
#  'mesenchymal': 8,
#  'transition': 8,
#  'stress': 8,
#  'liquid': 8,
#  'food': 8,
#  'intensity': 8,
#  'modulated': 8,
#  'automated': 8,
#  'bioinformatics': 7,
#  'feasibility': 7,
#  'graph': 7,
#  'ovarian': 7,
#  'stroke': 7,
#  'interaction': 7,
#  'knowledge': 7,
#  'papillomaviridae': 7,
#  'mellitus': 7,
#  'leukemia': 7,
#  'differential': 7,
#  'sequencing': 7,
#  'validation': 7,
#  'language': 7,
#  'body': 7,
#  'age': 7,
#  'cirrhosis': 7,
#  'spectrum': 7,
#  'hematopoietic': 7,
#  'disorders': 7,
#  'administration': 7,
#  'invasiveness': 7,
#  'immunotherapy': 7,
#  'solitary': 7,
#  'antigens': 7,
#  'influenza': 7,
#  'brain': 7,
#  'seq': 7,
#  'head': 7,
#  'neck': 7,
#  'positron': 7,
#  'features': 7,
#  'kidney': 7,
#  'dose': 7,
#  'amino': 7,
#  'smoking': 7,
#  'thyroid': 7,
#  'grading': 6,
#  'longitudinal': 6,
#  'toxicity': 6,
#  'syndrome': 6,
#  'endometrial': 6,
#  'number': 6,
#  'inflammation': 6,
#  'metabolic': 6,
#  'immune': 6,
#  'probability': 6,
#  'cellular': 6,
#  'side': 6,
#  'reactions': 6,
#  'segmentation': 6,
#  'node': 6,
#  'information': 6,
#  'system': 6,
#  'melanoma': 6,
#  'supply': 6,
#  'preventive': 6,
#  'wide': 6,
#  'tuberculosis': 6,
#  'prevalence': 6,
#  'suicide': 6,
#  'analytics': 6,
#  'nodules': 6,
#  'behavior': 6,
#  'long': 6,
#  'methylation': 6,
#  'transcriptome': 6,
#  'trees': 6,
#  'array': 6,
#  'stimulation': 6,
#  'economics': 6,
#  'heterogeneity': 5,
#  'alpha': 5,
#  'spectroscopy': 5,
#  'exposure': 5,
#  'dietary': 5,
#  'damage': 5,
#  'respiratory': 5,
#  'mri': 5,
#  'severity': 5,
#  'database': 5,
#  'supervised': 5,
#  'nodes': 5,
#  'hpv': 5,
#  'bayesian': 5,
#  'helicobacter': 5,
#  'cognitive': 5,
#  'disorder': 5,
#  'i': 5,
#  'combined': 5,
#  'pregnancy': 5,
#  'vaginal': 5,
#  'smears': 5,
#  'neoplasia': 5,
#  'targeted': 5,
#  'surveys': 5,
#  'cortex': 5,
#  'trials': 5,
#  'home': 5,
#  'hospitalization': 5,
#  'palliative': 5,
#  'rehabilitation': 5,
#  'evaluation': 5,
#  'diagnostics': 5,
#  'microbiome': 5,
#  'based': 5,
#  'chemically': 5,
#  'quantitative': 5,
#  'mycobacterium': 5,
#  'design': 5,
#  'period': 5,
#  'immunity': 5,
#  'surgical': 5,
#  'cord': 5,
#  'functional': 5,
#  'a': 5,
#  'technology': 5,
#  'infection': 5,
#  'evolution': 5,
#  'regulatory': 5,
#  'healthy': 5,
#  'translational': 5,
#  'individualized': 5,
#  'kaplan': 5,
#  'meier': 5,
#  'estimate': 5,
#  'immunohistochemistry': 5,
#  'adjuvant': 5,
#  'testing': 5,
#  'inference': 5,
#  'conditions': 5,
#  'reactive': 5,
#  'generation': 5,
#  'polymorphism': 5,
#  'oxidative': 5,
#  'performance': 5,
#  'energy': 5,
#  'epigenetics': 5,
#  'oligonucleotide': 5,
#  'repositioning': 5,
#  'atrophy': 5,
#  'smartphone': 5,
#  'beam': 5,
#  'negative': 4,
#  'contrast': 4,
#  'chemical': 4,
#  'environment': 4,
#  'mouth': 4,
#  'pelvic': 4,
#  'depression': 4,
#  'antioxidants': 4,
#  'serum': 4,
#  'fatty': 4,
#  'acids': 4,
#  'surveillance': 4,
#  'coronary': 4,
#  'genes': 4,
#  'auc': 4,
#  'receiver': 4,
#  'operating': 4,
#  'for': 4,
#  'intensive': 4,
#  'unit': 4,
#  'acute': 4,
#  'gastrectomy': 4,
#  'copy': 4,
#  'variations': 4,
#  'ultrasound': 4,
#  'illness': 4,
#  'mrna': 4,
#  'lymphoma': 4,
#  'protocols': 4,
#  'infant': 4,
#  'birth': 4,
#  'intraepithelial': 4,
#  'cross': 4,
#  'policy': 4,
#  'progression': 4,
#  'phenotype': 4,
#  'adrenocortical': 4,
#  'ensemble': 4,
#  'matrix': 4,
#  'observational': 4,
#  'skeletal': 4,
#  'twitter': 4,
#  'molecule': 4,
#  'host': 4,
#  'self': 4,
#  'visual': 4,
#  'density': 4,
#  'burden': 4,
#  'ai': 4,
#  'interactions': 4,
#  'antagonists': 4,
#  'docking': 4,
#  'isolation': 4,
#  'purification': 4,
#  'method': 4,
#  'transcription': 4,
#  'cytometry': 4,
#  'activation': 4,
#  'pet': 4,
#  'causality': 4,
#  'noncoding': 4,
#  'epigenesis': 4,
#  'integration': 4,
#  'mastectomy': 4,
#  'african': 4,
#  'swine': 4,
#  'antiviral': 4,
#  'nontuberculous': 4,
#  'neutralizing': 4,
#  'component': 4,
#  'cancers': 4,
#  'colposcopy': 4,
#  'peptides': 4,
#  'biomedical': 4,
#  'microrna': 4,
#  'proportional': 4,
#  'hazards': 4,
#  'monitoring': 4,
#  'mitochondria': 4,
#  'style': 4,
#  'physiopathology': 4,
#  'signal': 4,
#  'cnn': 4,
#  'dimensional': 4,
#  'diffusion': 4,
#  'histocompatibility': 4,
#  'class': 4,
#  'optimization': 4,
#  'population': 4,
#  'automation': 4,
#  'sclerosis': 4,
#  'neuromuscular': 4,
#  'devices': 4,
#  'binding': 4,
#  'instrumentation': 4,
#  'pattern': 4,
#  'recognition': 4,
#  'injuries': 4,
#  'groups': 4,
#  'comet': 4,
#  'triple': 3,
#  'synthetic': 3,
#  'reaction': 3,
#  'recurrent': 3,
#  'tumors': 3,
#  'occupational': 3,
#  'environmental': 3,
#  'analyses': 3,
#  'characteristic': 3,
#  'polyp': 3,
#  'anastomotic': 3,
#  'correlation': 3,
#  'angiography': 3,
#  'signaling': 3,
#  'cervix': 3,
#  'uteri': 3,
#  'lymphedema': 3,
#  'practice': 3,
#  'gestational': 3,
#  'monoclonal': 3,
#  'allogeneic': 3,
#  'patients': 3,
#  'ultrasonography': 3,
#  'pylori': 3,
#  'hypoxia': 3,
#  'major': 3,
#  'cardio': 3,
#  'cd8': 3,
#  'bibliometrics': 3,
#  'throughput': 3,
#  'sectional': 3,
#  'questionnaires': 3,
#  'personal': 3,
#  'weight': 3,
#  'regions': 3,
#  'generalized': 3,
#  'biomarker': 3,
#  'training': 3,
#  'education': 3,
#  'dataset': 3,
#  'transformation': 3,
#  'fusion': 3,
#  'clustering': 3,
#  'microscopy': 3,
#  'extraction': 3,
#  'adrenal': 3,
#  'end': 3,
#  'epidermal': 3,
#  'specific': 3,
#  'antigen': 3,
#  'ionization': 3,
#  'bone': 3,
#  'healthcare': 3,
#  'coding': 3,
#  'activator': 3,
#  'nuclear': 3,
#  'event': 3,
#  'extreme': 3,
#  'gradient': 3,
#  'pediatric': 3,
#  'arsenic': 3,
#  'wells': 3,
#  'outcomes': 3,
#  'hepatitis': 3,
#  'linear': 3,
#  'mutagenesis': 3,
#  'activity': 3,
#  'relationship': 3,
#  'lifestyle': 3,
#  'graft': 3,
#  'vs': 3,
#  'pca': 3,
#  'perioperative': 3,
#  'low': 3,
#  'dysplasia': 3,
#  'triage': 3,
#  'motor': 3,
#  'adenoma': 3,
#  'gastrointestinal': 3,
#  'metagenomics': 3,
#  'global': 3,
#  'chemoradiotherapy': 3,
#  'chinese': 3,
#  'phantoms': 3,
#  'enhancement': 3,
#  'development': 3,
#  'kinases': 3,
#  'kinase': 3,
#  'meta': 3,
#  'subtype': 3,
#  'lymphocyte': 3,
#  'vitamin': 3,
#  'net': 3,
#  'real': 3,
#  'b': 3,
#  'dependent': 3,
#  'effect': 3,
#  'lipid': 3,
#  'pathogenicity': 3,
#  'messenger': 3,
#  'egfr': 3,
#  'flow': 3,
#  'gland': 3,
#  'oxygen': 3,
#  'thoracic': 3,
#  'microarray': 3,
#  'indices': 3,
#  'fever': 3,
#  'causal': 3,
#  'precancerous': 3,
#  'competence': 3,
#  'radiography': 3,
#  'aortic': 3,
#  'valve': 3,
#  'registries': 3,
#  'p': 3,
#  'epitopes': 3,
#  'safety': 3,
#  'dynamic': 3,
#  'biotechnology': 3,
#  'sepsis': 3,
#  'dysfunction': 3,
#  'ductal': 3,
#  'communication': 3,
#  'glioma': 3,
#  'status': 3,
#  'intestinal': 3,
#  'principal': 3,
#  'injury': 3,
#  'survivors': 3,
#  'physical': 3,
#  'history': 3,
#  'tree': 3,
#  'transduction': 3,
#  'fluorodeoxyglucose': 3,
#  'f18': 3,
#  'theory': 3,
#  'section': 3,
#  'estrogen': 3,
#  'ms': 3,
#  'chromatography': 3,
#  'target': 3,
#  'entry': 3,
#  'reduction': 3,
#  'ethnology': 3,
#  'pneumonia': 3,
#  'whole': 3,
#  'susceptibility': 3,
#  'fistula': 3,
#  'betacoronavirus': 3,
#  'storage': 3,
#  'ion': 3,
#  'radiometry': 3,
#  'spatial': 3,
#  'anti': 3,
#  'ca2+': 3,
#  'fermented': 3,
#  'papaya': 3,
#  'il': 3,
#  'nerve': 3,
#  'adipose': 3,
#  'content': 3,
#  'products': 3,
#  'older': 3,
#  'super': 3,
#  'radiosurgery': 3,
#  'overweight': 3,
#  'lesion': 3,
#  'tool': 3,
#  'enzyme': 3,
#  'monte': 3,
#  'carlo': 3,
#  'guided': 3,
#  'lesions': 3,
#  'fuzzy': 3,
#  'mesothelioma': 3,
#  'pathways': 3,
#  'insulin': 3,
#  'cd4': 3,
#  'microsatellite': 3,
#  'variation': 3,
#  'ethnic': 3,
#  'maps': 3,
#  'predictor': 3,
#  'assay': 3,
#  'antibody': 2,
#  'characteristics': 2,
#  'variable': 2,
#  'heterografts': 2,
#  'histone': 2,
#  'gadolinium': 2,
#  'nomograms': 2,
#  'fetoproteins': 2,
#  'nomogram': 2,
#  'alzheimer': 2,
#  "alzheimer's": 2,
#  'sers': 2,
#  'biosensing': 2,
#  'nanomaterials': 2,
#  'proctitis': 2,
#  'fibers': 2,
#  'gut': 2,
#  'short': 2,
#  'chain': 2,
#  'vascular': 2,
#  'radiofrequency': 2,
#  'ablation': 2,
#  'centers': 2,
#  'protective': 2,
#  '(cnn)': 2,
#  'subtypes': 2,
#  'japan': 2,
#  'leakage': 2,
#  'reader': 2,
#  'variability': 2,
#  'diaphragmatic': 2,
#  'congenital': 2,
#  'qualitative': 2,
#  'drainage': 2,
#  'meningitis': 2,
#  'infectious': 2,
#  'embedding': 2,
#  'alphapapillomavirus': 2,
#  'attitudes': 2,
#  'text': 2,
#  'asian': 2,
#  'populations': 2,
#  'bnt162': 2,
#  'autologous': 2,
#  'lymphocytic': 2,
#  'malignancies': 2,
#  'hodgkin': 2,
#  'probabilistic': 2,
#  'hypothyroidism': 2,
#  'landscape': 2,
#  'overall': 2,
#  'behavioral': 2,
#  'depressive': 2,
#  'internet': 2,
#  'remission': 2,
#  'combinations': 2,
#  'calcinosis': 2,
#  'delivery': 2,
#  'newborn': 2,
#  'women': 2,
#  'belief': 2,
#  'q': 2,
#  'masks': 2,
#  'telemedicine': 2,
#  'loss': 2,
#  'saliva': 2,
#  'colon': 2,
#  'panel': 2,
#  'infiltrating': 2,
#  'unsupervised': 2,
#  'seer': 2,
#  'web': 2,
#  'ferroptosis': 2,
#  'lasso': 2,
#  'services': 2,
#  'triglycerides': 2,
#  'national': 2,
#  'examination': 2,
#  'accuracy': 2,
#  'targeting': 2,
#  'current': 2,
#  'record': 2,
#  'society': 2,
#  'international': 2,
#  'additive': 2,
#  'events': 2,
#  'guideline': 2,
#  'intervention': 2,
#  'groundwater': 2,
#  'pollutants': 2,
#  'contamination': 2,
#  'general': 2,
#  'enhanced': 2,
#  'myeloid': 2,
#  'prognostic': 2,
#  'precursor': 2,
#  'mutagens': 2,
#  'structure': 2,
#  'homologous': 2,
#  'informatics': 2,
#  'mechanism': 2,
#  'neurocognitive': 2,
#  'report': 2,
#  'radiology': 2,
#  'personnel': 2,
#  'attempted': 2,
#  'immunologic': 2,
#  'grade': 2,
#  'fluorescent': 2,
#  'communicable': 2,
#  'emerging': 2,
#  'hospital': 2,
#  'adjusted': 2,
#  'years': 2,
#  'augmentation': 2,
#  'exposome': 2,
#  'pharmacokinetics': 2,
#  'lab': 2,
#  'ligands': 2,
#  'domains': 2,
#  'autoantibodies': 2,
#  'double': 2,
#  'blind': 2,
#  'immunization': 2,
#  'correlates': 2,
#  'protection': 2,
#  'variants': 2,
#  'transfusion': 2,
#  'donors': 2,
#  'donor': 2,
#  'e': 2,
#  'histological': 2,
#  'her2': 2,
#  'pathogenesis': 2,
#  'fmri': 2,
#  'basal': 2,
#  'autofluorescence': 2,
#  'margin': 2,
#  'endothelial': 2,
#  'papillary': 2,
#  'strategy': 2,
#  'nanotechnology': 2,
#  'perception': 2,
#  'combination': 2,
#  'hybrid': 2,
#  'post': 2,
#  'modification': 2,
#  'apoptosis': 2,
#  'oropharyngeal': 2,
#  'program': 2,
#  'cystic': 2,
#  'fibrosis': 2,
#  'multimodal': 2,
#  'autoencoders': 2,
#  'logical': 2,
#  'preschool': 2,
#  'macrophages': 2,
#  'units': 2,
#  'metastases': 2,
#  'directed': 2,
#  'polymerase': 2,
#  'relapse': 2,
#  'programs': 2,
#  'senescence': 2,
#  'mycobacteria': 2,
#  'man': 2,
#  'bacterial': 2,
#  'bloodstream': 2,
#  'pathogenic': 2,
#  'dengue': 2,
#  'max': 2,
#  'relevance': 2,
#  'antioxidant': 2,
#  'bioterrorism': 2,
#  'cytology': 2,
#  'parkinson': 2,
#  'bronchoalveolar': 2,
#  'lavage': 2,
#  'fluid': 2,
#  'germ': 2,
#  'whites': 2,
#  'australia': 2,
#  'reference': 2,
#  'resistance': 2,
#  'melatonin': 2,
#  'polyphenols': 2,
#  'rule': 2,
#  'signature': 2,
#  'epigenetic': 2,
#  'rnas': 2,
#  'neovascularization': 2,
#  'pathologic': 2,
#  'angiogenesis': 2,
#  'cognition': 2,
#  'phenotypes': 2,
#  'species': 2,
#  'profile': 2,
#  'adaptive': 2,
#  'fibrinogen': 2,
#  'traditional': 2,
#  'symptoms': 2,
#  'sampling': 2,
#  'autism': 2,
#  'dysbiosis': 2,
#  'spain': 2,
#  'kingdom': 2,
#  'malnutrition': 2,
#  'graphics': 2,
#  'lncrna': 2,
#  'laryngeal': 2,
#  'carotenoids': 2,
#  'subunit': 2,
#  'metalloproteinases': 2,
#  'urokinase': 2,
#  'plasminogen': 2,
#  'photon': 2,
#  'thorax': 2,
#  'cardiotoxicity': 2,
#  'cardiac': 2,
#  'activities': 2,
#  'daily': 2,
#  'living': 2,
#  'osteoporosis': 2,
#  'fractures': 2,
#  'fracture': 2,
#  'pharmaceutical': 2,
#  'approval': 2,
#  'phenotyping': 2,
#  'analogs': 2,
#  'derivatives': 2,
#  'electron': 2,
#  'dnn': 2,
#  'fingerprint': 2,
#  'induction': 2,
#  'decay': 2,
#  'infrared': 2,
#  'gas': 2,
#  'sample': 2,
#  'size': 2,
#  'ist': 2,
#  'iterative': 2,
#  'lstm': 2,
#  'ml': 2,
#  'perceptron': 2,
#  'nmr': 2,
#  'rnn': 2,
#  'smiles': 2,
#  'school': 2,
#  'm': 2,
#  'ratio': 2,
#  'genotype': 2,
#  'peritoneal': 2,
#  ...}

# %%
# ok but were do i check for matches? title? keywords? abstract?
most_common_keywords = list(dic.keys())[0:10]

# %%
search_term
# Out:
# ['machine', 'learning', 'cancer', 'prevention']

# %%
most_common = search_term + most_common_keywords
set(most_common)
# Out:
# {'cancer',
#  'diagnosis',
#  'genetics',
#  'humans',
#  'imaging',
#  'learning',
#  'machine',
#  'methods',
#  'neoplasms',
#  'pathology',
#  'prevention'}

# %%
abstarcts = df['abstarct'].tolist()
scores = []
for abstarct in abstarcts:
    abstarct = process_text(abstarct)
    matchs = 0
    for word in most_common:
        if word in abstarct:
            matchs += 1
    scores.append(matchs/len(most_common))

# %%
len(scores)
# Out:
# 500

# %%
df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2['score'] = df2['score'].apply(lambda x: x/max(df2['score']))
df2
# Out:
#                                                  title     score
# 42   abstracts of presentations at the association ...  1.000000
# 217  a primer on applying ai synergistically with d...  0.846154
# 71   recent advancement in cancer diagnosis using m...  0.769231
# 77   srg vote  predicting mirna gene relationships ...  0.769231
# 275  computer aided diagonosis for colorectal cance...  0.769231
# ..                                                 ...       ...
# 394  artificial intelligence in dermato oncology  a...  0.000000
# 402            ascent of machine learning in medicine   0.000000
# 330  letter to the editor  response to giardiello d...  0.000000
# 353                     hunting for new drugs with ai   0.000000
# 282  comment on "prediction of the 1 year risk of i...  0.000000
#
# [500 rows x 2 columns]

# %%
for elem in df2.head(10)['title'].values:
        print(elem)
        print()
# Out:
# abstracts of presentations at the association of clinical scientists 143(rd)meeting louisville  ky may 11 14 2022
#
# a primer on applying ai synergistically with domain expertise to oncology
#
# recent advancement in cancer diagnosis using machine learning and deep learningtechniques  a comprehensive review
#
# srg vote  predicting mirna gene relationships via embedding and lstm ensemble
#
# computer aided diagonosis for colorectal cancer using deep learning with visualexplanations
#
# radiomics in stratification of pancreatic cystic lesions  machine learning inaction
#
# cohort profile  chinese cervical cancer clinical study
#
# artificial intelligence for the prevention and clinical management ofhepatocellular carcinoma
#
# low grade chronic inflammation and immune alterations in childhood and adolescentcancer survivors  a contribution to accelerated aging?
#
# data driven methods for advancing precision oncology

# %%
search_term = 'machine learning cancer prevention'
search_term = process_text(search_term)
search_term = search_term.split()

scores = []
titles = df['title'].tolist()
for title in titles:
    title = process_text(title)
    matchs = 0
    for word in most_common:
        if word in title:
            matchs += 1
    scores.append(matchs/len(most_common))

df2 = pd.DataFrame(list(zip(titles, scores)), columns = ['title', 'score'])
df2 = df2.sort_values(by=['score'], ascending=False)
df2
# Out:
#                                                  title     score
# 30   Decoding the Role of Epigenetics in Breast Can...  0.571429
# 82   Effective Image Processing and Segmentation-Ba...  0.500000
# 130  Methodological quality of machine learning-bas...  0.500000
# 71   Recent advancement in cancer diagnosis using m...  0.500000
# 377  C-HMOSHSSA: Gene selection for cancer classifi...  0.500000
# ..                                                 ...       ...
# 251  Cervical screening in high-income countries: t...  0.000000
# 262  Integration of a vertebral fracture identifica...  0.000000
# 263  COVID19 Drug Repository: text-mining the liter...  0.000000
# 272  Exploring chromosomal structural heterogeneity...  0.000000
# 250  GAERF: predicting lncRNA-disease associations ...  0.000000
#
# [500 rows x 2 columns]
